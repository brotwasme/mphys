# %%
import os.path
import numpy as np
import matplotlib.pyplot as plt
import scipy
import refnx
from refnx.dataset import ReflectDataset, Data1D
from refnx.analysis import Transform, CurveFitter, Objective, Model, Parameter, GlobalObjective
from refnx.reflect import SLD, Slab, ReflectModel
# from sepObjectiveGO import getObjective as gO
# import make_sim_data as msd
# import lipidBilayerAsGiven.SLD_maker 
import data_in as di
from protein.LipidLeafletWithProtein_builtOn3 import LipidLeafletWithProtien as LipidLeaflet
from protein.protrusion2 import Protrusion

from refnx._lib import flatten
from refnx._lib import unique as f_unique

print('refnx: %s\nscipy: %s\nnumpy: %s' % (refnx.version.version,
                   scipy.version.version, np.version.version))
# %matplotlib inline
SEED = 12345
# Out:
# refnx: 0.1.9
# scipy: 1.3.0
# numpy: 1.16.4

# %%
# dataD2o = Data1D(data=di.data_in("lipidBilayerData/54696_97_edit.txt"))
# dataD2o.name="d2o"
# dataPmw = Data1D(data=di.data_in("lipidBilayerData/54699_00_edit.txt"))
# dataPmw.name="pmw"

dataAcmw = Data1D(data=di.data_in("protein/54613_14edit.txt"))
dataAcmw.name="acm"
dataPmw = Data1D(data=di.data_in("protein/54616_17edit.txt"))
dataPmw.name="pmw"
dataD2o = Data1D(data=di.data_in("protein/10_11_d2o.txt"))
dataD2o.name="d2o"
plt.errorbar(dataAcmw.data[0],dataAcmw.data[1],dataAcmw.data[2])
plt.errorbar(dataPmw.data[0],dataPmw.data[1],dataPmw.data[2])
plt.errorbar(dataD2o.data[0],dataD2o.data[1],dataD2o.data[2])
plt.yscale("log")
plt.show()
# Out:
# csv
# cvs-collecting
# csv
# cvs-collecting
# csv
# cvs-collecting

# %%
name = "bilayer"

d2o = SLD(6.34, "D2O")
pmw = SLD(2.35, "Protein Matched Water")
acmw = SLD(0.00, "ACMW")
air = SLD(0.00, "Air")

d2o.real.setp(vary=True, bounds=(5.35, 6.35)) # bounds=(5.9, 6.35))
pmw.real.setp(vary=True, bounds=(1.35, 3.35))
acmw.real.setp(vary=True, bounds=(-0.56, 1))

apm = Parameter(value=101, name='%s - area_per_molecule' % name,
                bounds=(100, 200), vary=False)

#Define all the neutron b's
bc = 0.6646e-4  #Carbon
bo = 0.5804e-4  #Oxygen
bh = -0.3739e-4 #Hydrogen
bp = 0.513e-4   #Phosphorus
bn = 0.936e-4   #Nitrogen
bd = 0.6671e-4  #Deuterium

#Formulae of the molecule sections...
CH2 = (1*bc) + (2*bh)
CH = (1*bc) + (1*bh)
CH3 = (1*bc) + (3*bh)
D2O = (2*bd) + (1*bo)
H2O = (2*bh) + (1*bo)

# Calculate mole fraction of D2O from the bulk SLD..
# d2o_molfr = (1/D2O-H2O)*(contrast*27.64)-H2O
# wMol = (d2o_molfr * D2O) + ((1-d2o_molfr)*H2O)

#sum b's of all the different fragments
b_tails = Parameter(value=(28*CH2) + (2*CH) + (2*CH3),
                       name='%s - b_tails_real' % name)

sum_popc_heads = (8*bo) + (1*bp) + (1*bn) + (2*bc) + (4*CH2) + (3*CH3) + (1*CH)
sum_popg_heads = (10*bo) + (1*bp) + (2*bc) + (4*CH2) + (2*CH) + (2*bh)
b_heads = Parameter(value=(3*(sum_popc_heads) + (sum_popg_heads))/4,
                        name='%s - b_heads_real' % name)

#monolayer compositions
#sum_m_tails = (34*CH2) + (2*CH3);
#sum_m_heads = (1*bn) + (2*CH3) + (Waters_per_headD * wMol);

#volumes of each fragment
vCH2 = 27.7
nCH2 = 30
vCH3 = 54.6
vm_tails = Parameter(value=(nCH2 * vCH2) + (2 * vCH3),
            name='%s - volume_tails' % name) #
vm_heads = Parameter(value=331,
            name='%s - volume_heads' % name)  #
vm_water = Parameter(value=29.7,
            name='%s - water_vm' % name)

#thickness
thickness_tails = Parameter(11, # 6., #value=vm_tails.value/apm.value,
            name='%s - thickness_tails' % name,
            bounds=(1,30),  #3, #(1-0.75)*vm_tails.value/apm.value,
                      #9), #(1+0.75)*vm_tails.value/apm.value),
               vary=True)
thickness_heads = Parameter(value= 6, #11., #vm_heads.value/apm.value,
            name='%s - thickness_heads' % name,
            bounds=(1,30),  #  9, #(1-0.75)*vm_heads.value/apm.value,
                      # 20), #(1+0.75)*vm_heads.value/apm.value),
               vary=True)

rough_head_tail = Parameter(value=2,
            name='%s - roughs' % name,
            bounds=(0,10), vary=True)

rough_top = Parameter(value=2,
            name='%s - roughs' % name,
            bounds=(0,10), vary=True)
# rough_bot = rough_top
# rough_head_ = Parameter(value=2.0,
#             name='%s - rough_bot' % name,
#             bounds=(0,10), vary=True)

waters_per_head = Parameter(
            value=2.8,
            name="{} - Waters Per Head".format(name),
            bounds=(0, 20), vary=True)

waters_per_tail = Parameter(
            value=1,
            name="{} - Waters Per Tail".format(name),
            bounds=(0, 10), vary=True)

# b_mscl = Parameter(
#             value= ,
#             name="{} - b_protein_real".format(name),
#             vary=False)

vm_mscl = Parameter(
            value=74937.5 + 19749,
            name="{} - volume_protein".format(name),
            vary=False)

PLRatio = Parameter(
            value= 0.75,
            name="{} - ratio protein to bilayer".format(name),
            bounds=(0.5, 1),vary=True)

# %%
# apm, b_heads, vm_heads, thickness_heads
# b_tails, vm_tails, thickness_tails, rough_head_tail
# rough_preceding_mono, head_solvent


# head_solvent_d2o = SLD(6.07, "D2O in bilayer")
# head_solvent_d2o.real.setp(6.07, vary=True, bounds=(5.35, 6.35))
upper_lipid_d2o = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
    vm_water, waters_per_head, waters_per_tail,
    vm_mscl, PLRatio, d2o, d2o,
    reverse_monolayer=False, name="upper_lipid_d2o")

lower_lipid_d2o = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
    vm_water, waters_per_head, waters_per_tail,
    vm_mscl, PLRatio, d2o, d2o,
    reverse_monolayer=True, name="lower_lipid_d2o")


# head_solvent_pmw = SLD(2.35, "Protein Matched Water in bilayer")
# head_solvent_pmw.real.setp(2.34, vary=True, bounds=(1.35, 3.35))
upper_lipid_pmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
    vm_water, waters_per_head, waters_per_tail,
    vm_mscl, PLRatio, pmw, pmw,
    reverse_monolayer=False, name="upper_lipid_pmw")

lower_lipid_pmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
    vm_water, waters_per_head, waters_per_tail,
    vm_mscl, PLRatio, pmw, pmw,
    reverse_monolayer=True, name="lower_lipid_pmw")


upper_lipid_acmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
    vm_water, waters_per_head, waters_per_tail,
    vm_mscl, PLRatio, acmw, acmw,
    reverse_monolayer=False, name="upper_lipid_acmw")

lower_lipid_acmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
    vm_water, waters_per_head, waters_per_tail,
    vm_mscl, PLRatio, acmw, acmw,
    reverse_monolayer=True, name="lower_lipid_acmw")

# %%
# to changing to
solution_thickness = Parameter(value=14.3, bounds=(6, 25), vary=True,
            name='thickness_solution')

# rough_preceding_solution = Parameter(value=4.6, bounds=(0, 20), vary=True,
#             name='rough_preceding_solution')


rough_preceding_solution = Parameter(value=4.6, bounds=(0, 20), vary=True,
            name='rough_preceding_solution')#, constraint=)


structure_d2o  = air(0, 0) | d2o(solution_thickness, rough_preceding_solution)  | upper_lipid_d2o  | lower_lipid_d2o  | d2o(solution_thickness, rough_top)
structure_pmw  = air(0, 0) | pmw(solution_thickness, rough_preceding_solution)  | upper_lipid_pmw  | lower_lipid_pmw  | pmw(solution_thickness, rough_top)
structure_acmw = air(0, 0) | acmw(solution_thickness, rough_preceding_solution) | upper_lipid_acmw | lower_lipid_acmw | acmw(solution_thickness, rough_top)

# structure_d2o  = air(0, 0) | d2o(solution_thickness, rough_preceding_solution)  | upper_lipid_d2o  | lower_lipid_d2o  | d2o(solution_thickness, rough_preceding_solution)
# structure_pmw  = air(0, 0) | pmw(solution_thickness, rough_preceding_solution)  | upper_lipid_pmw  | lower_lipid_pmw  | pmw(solution_thickness, rough_preceding_solution)
# structure_acmw = air(0, 0) | acmw(solution_thickness, rough_preceding_solution) | upper_lipid_acmw | lower_lipid_acmw | acmw(solution_thickness, rough_preceding_solution)

structure_d2o.name = "d2o"
structure_pmw.name = "protein matched water"
structure_acmw.name = "ACMW"

plt.plot(*structure_d2o.sld_profile(),label="structure_d2o")
plt.ylabel('SLD /$10^{-6} \AA^{-2}$')
plt.xlabel('distance / $\AA$')
plt.plot(*structure_pmw.sld_profile(),label="structure_pmw")
plt.ylabel('SLD /$10^{-6} \AA^{-2}$')
plt.xlabel('distance / $\AA$')
plt.plot(*structure_acmw.sld_profile(),label="structure_acmw")
plt.ylabel('SLD /$10^{-6} \AA^{-2}$')
plt.xlabel('distance / $\AA$')
plt.show();
print(structure_d2o.parameters)
print(structure_pmw.parameters)
print(structure_acmw.parameters)
# Out:
# ________________________________________________________________________________
# Parameters: 'Structure - d2o'
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=6.34          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=4.6          , bounds=[0, 20]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'upper_lipid_d2o'
# <Parameter:'bilayer - area_per_molecule', value=758.945 (fixed)  , bounds=[100, 200]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_d2o - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=331 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=6          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_d2o - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=940.2 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=11          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.34          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.34          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - water_vm', value=29.7 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - Waters Per Head', value=2.8          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=1          , bounds=[0, 10]>
# <Parameter:'bilayer - Waters Per Head', value=2.8          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=1          , bounds=[0, 10]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.75          , bounds=[0.5, 1]>
# ________________________________________________________________________________
# Parameters: 'lower_lipid_d2o'
# <Parameter:'bilayer - area_per_molecule', value=758.945 (fixed)  , bounds=[100, 200]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_d2o - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=331 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=6          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_d2o - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=940.2 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=11          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.34          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.34          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - water_vm', value=29.7 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - Waters Per Head', value=2.8          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=1          , bounds=[0, 10]>
# <Parameter:'bilayer - Waters Per Head', value=2.8          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=1          , bounds=[0, 10]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.75          , bounds=[0.5, 1]>
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=6.34          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Structure - protein matched water'
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=4.6          , bounds=[0, 20]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'upper_lipid_pmw'
# <Parameter:'bilayer - area_per_molecule', value=758.945 (fixed)  , bounds=[100, 200]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_pmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=331 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=6          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_pmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=940.2 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=11          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - water_vm', value=29.7 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - Waters Per Head', value=2.8          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=1          , bounds=[0, 10]>
# <Parameter:'bilayer - Waters Per Head', value=2.8          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=1          , bounds=[0, 10]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.75          , bounds=[0.5, 1]>
# ________________________________________________________________________________
# Parameters: 'lower_lipid_pmw'
# <Parameter:'bilayer - area_per_molecule', value=758.945 (fixed)  , bounds=[100, 200]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_pmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=331 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=6          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_pmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=940.2 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=11          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - water_vm', value=29.7 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - Waters Per Head', value=2.8          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=1          , bounds=[0, 10]>
# <Parameter:'bilayer - Waters Per Head', value=2.8          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=1          , bounds=[0, 10]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.75          , bounds=[0.5, 1]>
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Structure - ACMW'
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:     'ACMW'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter: 'ACMW - sld'  , value=0          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=4.6          , bounds=[0, 20]>
# <Parameter:'ACMW - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'upper_lipid_acmw'
# <Parameter:'bilayer - area_per_molecule', value=758.945 (fixed)  , bounds=[100, 200]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_acmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=331 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=6          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_acmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=940.2 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=11          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter: 'ACMW - sld'  , value=0          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter: 'ACMW - sld'  , value=0          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - water_vm', value=29.7 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - Waters Per Head', value=2.8          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=1          , bounds=[0, 10]>
# <Parameter:'bilayer - Waters Per Head', value=2.8          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=1          , bounds=[0, 10]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.75          , bounds=[0.5, 1]>
# ________________________________________________________________________________
# Parameters: 'lower_lipid_acmw'
# <Parameter:'bilayer - area_per_molecule', value=758.945 (fixed)  , bounds=[100, 200]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_acmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=331 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=6          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_acmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=940.2 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=11          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter: 'ACMW - sld'  , value=0          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter: 'ACMW - sld'  , value=0          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - water_vm', value=29.7 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - Waters Per Head', value=2.8          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=1          , bounds=[0, 10]>
# <Parameter:'bilayer - Waters Per Head', value=2.8          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=1          , bounds=[0, 10]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.75          , bounds=[0.5, 1]>
# ________________________________________________________________________________
# Parameters:     'ACMW'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter: 'ACMW - sld'  , value=0          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'ACMW - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>

# %%
# right_protrusion_d2o.parameters

# %%
# print(structure_acmw.slabs())
# print(structure_pmw.slabs())
# print(structure_d2o.slabs())

def logp_extra(model, data):
    returns = 0
    if rough_top.value > thickness_heads.value:
        returns += -np.inf
#         print("rough, thickness: ", rough_top.value, thickness_heads.value)
    return returns

# %%
scale=0.5538
print(dataD2o.y.max(), dataPmw.y.max(), dataAcmw.y.max())
print(dataD2o.y.min(), dataPmw.y.min(), dataAcmw.y.min())
model1 = ReflectModel(structure_d2o)
model1.scale.setp(scale, vary=False)#0.5, vary=True, bounds=(0.5, 0.6))#0.25, 1)) #1./dataD2o.y.max()
if dataD2o.y.min()<0:
    d2oUpBound = dataD2o.y.min() * 0.2
    d2oLoBound = dataD2o.y.min() * 1.8
else:
    d2oUpBound = dataD2o.y.min() * 1.8
    d2oLoBound = dataD2o.y.min() * 0.2
model1.bkg.setp(dataD2o.y.min(),vary=True,bounds=(d2oLoBound, d2oUpBound))

model2 = ReflectModel(structure_pmw)
model2.scale.setp(scale, vary=False)#0.5, vary=True, bounds=(0.5, 0.6))#0.25, 1))#(1./dataPmw.y.max(), vary=False)
if dataPmw.y.min()<0:
    pmwUpBound = dataPmw.y.min() * 0.2
    pmwLoBound = dataPmw.y.min() * 1.8
else:
    pmwUpBound = dataPmw.y.min() * 1.8
    pmwLoBound = dataPmw.y.min() * 0.2
model2.bkg.setp(dataPmw.y.min(),vary=True,bounds=(pmwLoBound, pmwUpBound))

model3 = ReflectModel(structure_acmw)
model3.scale.setp(scale, vary=False)#0.5, vary=True, bounds=(0.5, 0.6))#0.25, 1)) #1./dataAcmw.y.max(), vary=False)
if dataAcmw.y.min()<0:
    acmwUpBound = dataAcmw.y.min() * 0.2
    acmwLoBound = dataAcmw.y.min() * 1.8
else:
    acmwUpBound = dataAcmw.y.min() * 1.8
    acmwLoBound = dataAcmw.y.min() * 0.2
model3.bkg.setp(dataAcmw.y.min(),vary=True,bounds=(acmwLoBound, acmwUpBound))



objective1 = Objective(model1, dataD2o, transform=Transform("logY"))#, logp_extra =logp_extra)
objective2 = Objective(model2, dataPmw, transform=Transform("logY"))#, logp_extra =logp_extra)
objective3 = Objective(model3, dataAcmw, transform=Transform("logY"))#, logp_extra =logp_extra)
gobjective = GlobalObjective([objective1,objective2,objective3])
# Out:
# 0.562 0.0655 0.000924
# 1.8e-06 3.02e-06 1.73e-06

# %%
print("")
print("logp:",gobjective.logp())
[[print(i,param.name+":",param.value, param.bounds,"logp:", param.logp())] for i,param in enumerate(gobjective.varying_parameters())];
# print
# [[print(i,param)] for i,param in enumerate(gobjective.parameters)];# if "area_per_molecule" in param.name];
# gobjective.parameters
print()
# [[print(i,param.name)] for i,param in enumerate(gobjective.parameters)];# if "area" in param
print(list(f_unique(p for p in flatten(gobjective.parameters) if "area" in p.name)))
# Out:
# logp: -22.090031695490907
# 0 bkg: 1.8e-06 [3.6e-07, 3.24e-06] logp: 12.75772026381642
# 1 thickness_solution: 14.3 [6, 25] logp: -2.9444389791664407
# 2 D2O - sld: 6.34 [5.35, 6.35] logp: 0.0
# 3 rough_preceding_solution: 4.6 [0, 20] logp: -2.995732273553991
# 4 bilayer - thickness_heads: 6.0 [1, 30] logp: -3.367295829986474
# 5 bilayer - thickness_tails: 11.0 [1, 30] logp: -3.367295829986474
# 6 bilayer - roughs: 2.0 [0, 10] logp: -2.3025850929940455
# 7 bilayer - Waters Per Head: 2.8 [0, 20] logp: -2.995732273553991
# 8 bilayer - Waters Per Tail: 1.0 [0, 10] logp: -2.3025850929940455
# 9 bilayer - ratio protein to bilayer: 0.75 [0.5, 1] logp: 0.6931471805599453
# 10 bkg: 3.02e-06 [6.040000000000001e-07, 5.436e-06] logp: 12.24025009733176
# 11 Protein Matched Water - sld: 2.35 [1.35, 3.35] logp: -0.6931471805599453
# 12 bkg: 1.73e-06 [3.46e-07, 3.114e-06] logp: 12.79738552020885
# 13 ACMW - sld: 0.0 [-0.56, 1] logp: -0.4446858212614458
#
# [Parameter(value=758.9454411764706, name='bilayer - area_per_molecule', vary=False, bounds=Interval(lb=100, ub=200), constraint=None)]

# %%
# %%time
choose = 2
if choose==0:
    fitter = CurveFitter(gobjective)
    res = fitter.fit("differential_evolution", target="nlpost")#, seed=SEED)
if choose==1:
    fitter = CurveFitter(gobjective)
    fitter.sample(400)
    fitter.reset()
    res = fitter.sample(15, nthin=100)
if choose==2:
    from dynesty import DynamicNestedSampler
    from dynesty import plotting as dyplot
    from CFitter import CFitter
    fitter = CFitter(gobjective)
    # DynamicNestedSampler
    DNSampler = DynamicNestedSampler(fitter.logl, fitter.priorTransform, fitter.nDim())
    DNSampler.run_nested(dlogz_init=0.05) # was 0.01
    res1 = DNSampler.results
print("done")
# Out:
# 12633it [32:01,  6.44it/s, batch: 0 | bound: 167 | nc: 25 | ncall: 291640 | eff(%):  4.324 | loglstar:   -inf < -37.404 <    inf | logz: -66.144 +/-  0.332 | dlogz: 124.909 >  0.050]     C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12795it [32:37,  6.25it/s, batch: 0 | bound: 170 | nc: 25 | ncall: 297115 | eff(%):  4.299 | loglstar:   -inf < -28.347 <    inf | logz: -57.264 +/-  0.334 | dlogz: 115.696 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12933it [33:06,  6.13it/s, batch: 0 | bound: 173 | nc: 25 | ncall: 301621 | eff(%):  4.281 | loglstar:   -inf < -21.416 <    inf | logz: -50.506 +/-  0.334 | dlogz: 108.652 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12934it [33:10,  1.22s/it, batch: 0 | bound: 174 | nc: 562 | ncall: 302183 | eff(%):  4.273 | loglstar:   -inf < -21.393 <    inf | logz: -50.456 +/-  0.334 | dlogz: 108.603 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 13398it [34:37,  5.58it/s, batch: 0 | bound: 181 | nc: 25 | ncall: 315509 | eff(%):  4.240 | loglstar:   -inf < -1.941 <    inf | logz: -31.471 +/-  0.338 | dlogz: 88.673 >  0.050]    C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 13502it [35:04,  6.19it/s, batch: 0 | bound: 184 | nc: 25 | ncall: 319632 | eff(%):  4.218 | loglstar:   -inf <  2.302 <    inf | logz: -27.700 +/-  0.340 | dlogz: 84.704 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13596it [35:28,  6.24it/s, batch: 0 | bound: 186 | nc: 25 | ncall: 323276 | eff(%):  4.199 | loglstar:   -inf <  5.127 <    inf | logz: -24.682 +/-  0.339 | dlogz: 81.485 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 13820it [36:14,  6.14it/s, batch: 0 | bound: 190 | nc: 25 | ncall: 330304 | eff(%):  4.178 | loglstar:   -inf < 13.617 <    inf | logz: -16.768 +/-  0.342 | dlogz: 73.126 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 13922it [36:46,  6.21it/s, batch: 0 | bound: 193 | nc: 25 | ncall: 335252 | eff(%):  4.147 | loglstar:   -inf < 16.768 <    inf | logz: -13.655 +/-  0.343 | dlogz: 69.805 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 13956it [37:04,  6.23it/s, batch: 0 | bound: 195 | nc: 25 | ncall: 338056 | eff(%):  4.122 | loglstar:   -inf < 17.698 <    inf | logz: -12.759 +/-  0.343 | dlogz: 68.840 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14062it [37:29,  6.26it/s, batch: 0 | bound: 197 | nc: 25 | ncall: 341723 | eff(%):  4.109 | loglstar:   -inf < 20.727 <    inf | logz: -9.931 +/-  0.344 | dlogz: 65.800 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14097it [37:47,  6.17it/s, batch: 0 | bound: 199 | nc: 25 | ncall: 344509 | eff(%):  4.086 | loglstar:   -inf < 21.776 <    inf | logz: -9.005 +/-  0.344 | dlogz: 64.806 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14149it [38:14,  5.40it/s, batch: 0 | bound: 201 | nc: 25 | ncall: 348365 | eff(%):  4.056 | loglstar:   -inf < 23.117 <    inf | logz: -7.654 +/-  0.345 | dlogz: 63.348 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14209it [38:35,  1.12s/it, batch: 0 | bound: 204 | nc: 527 | ncall: 351488 | eff(%):  4.037 | loglstar:   -inf < 24.841 <    inf | logz: -6.159 +/-  0.345 | dlogz: 61.736 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14380it [39:09,  5.46it/s, batch: 0 | bound: 206 | nc: 25 | ncall: 356290 | eff(%):  4.030 | loglstar:   -inf < 29.785 <    inf | logz: -1.559 +/-  0.348 | dlogz: 56.794 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14424it [39:37,  5.22it/s, batch: 0 | bound: 208 | nc: 25 | ncall: 359861 | eff(%):  4.003 | loglstar:   -inf < 30.732 <    inf | logz: -0.491 +/-  0.348 | dlogz: 55.633 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14641it [40:32,  5.11it/s, batch: 0 | bound: 212 | nc: 25 | ncall: 366801 | eff(%):  3.986 | loglstar:   -inf < 36.427 <    inf | logz:  4.930 +/-  0.350 | dlogz: 49.775 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14976it [41:44,  5.79it/s, batch: 0 | bound: 218 | nc: 25 | ncall: 376994 | eff(%):  3.967 | loglstar:   -inf < 43.953 <    inf | logz: 11.628 +/-  0.352 | dlogz: 42.411 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15039it [42:10,  5.69it/s, batch: 0 | bound: 220 | nc: 25 | ncall: 380576 | eff(%):  3.946 | loglstar:   -inf < 45.190 <    inf | logz: 12.920 +/-  0.353 | dlogz: 44.109 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15186it [42:42,  5.71it/s, batch: 0 | bound: 223 | nc: 25 | ncall: 385126 | eff(%):  3.938 | loglstar:   -inf < 48.400 <    inf | logz: 15.742 +/-  0.355 | dlogz: 45.277 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15257it [43:06,  5.77it/s, batch: 0 | bound: 225 | nc: 25 | ncall: 388476 | eff(%):  3.922 | loglstar:   -inf < 49.913 <    inf | logz: 17.145 +/-  0.356 | dlogz: 43.732 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15455it [43:52,  5.74it/s, batch: 0 | bound: 229 | nc: 25 | ncall: 394991 | eff(%):  3.908 | loglstar:   -inf < 53.351 <    inf | logz: 20.510 +/-  0.357 | dlogz: 39.966 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15513it [44:17,  5.88it/s, batch: 0 | bound: 231 | nc: 25 | ncall: 398540 | eff(%):  3.888 | loglstar:   -inf < 54.412 <    inf | logz: 21.344 +/-  0.357 | dlogz: 43.687 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15595it [44:45,  5.50it/s, batch: 0 | bound: 234 | nc: 25 | ncall: 402567 | eff(%):  3.869 | loglstar:   -inf < 55.874 <    inf | logz: 22.649 +/-  0.358 | dlogz: 42.217 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15722it [45:30,  5.87it/s, batch: 0 | bound: 237 | nc: 25 | ncall: 409085 | eff(%):  3.839 | loglstar:   -inf < 57.799 <    inf | logz: 24.523 +/-  0.359 | dlogz: 40.087 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15826it [46:04,  5.38it/s, batch: 0 | bound: 240 | nc: 25 | ncall: 413876 | eff(%):  3.819 | loglstar:   -inf < 59.323 <    inf | logz: 25.907 +/-  0.360 | dlogz: 38.494 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16017it [46:51,  5.68it/s, batch: 0 | bound: 244 | nc: 25 | ncall: 420548 | eff(%):  3.804 | loglstar:   -inf < 62.611 <    inf | logz: 28.702 +/-  0.362 | dlogz: 35.319 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16213it [47:47,  5.79it/s, batch: 0 | bound: 248 | nc: 25 | ncall: 428512 | eff(%):  3.779 | loglstar:   -inf < 65.378 <    inf | logz: 31.242 +/-  0.364 | dlogz: 32.386 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16268it [48:14,  5.85it/s, batch: 0 | bound: 250 | nc: 25 | ncall: 432389 | eff(%):  3.758 | loglstar:   -inf < 66.161 <    inf | logz: 31.872 +/-  0.364 | dlogz: 31.647 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16372it [48:47,  5.88it/s, batch: 0 | bound: 253 | nc: 25 | ncall: 437042 | eff(%):  3.742 | loglstar:   -inf < 67.593 <    inf | logz: 33.155 +/-  0.365 | dlogz: 30.155 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16447it [49:12,  6.01it/s, batch: 0 | bound: 255 | nc: 25 | ncall: 440591 | eff(%):  3.729 | loglstar:   -inf < 68.580 <    inf | logz: 33.994 +/-  0.366 | dlogz: 29.166 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16581it [49:50,  5.74it/s, batch: 0 | bound: 258 | nc: 25 | ncall: 446140 | eff(%):  3.712 | loglstar:   -inf < 70.292 <    inf | logz: 35.510 +/-  0.367 | dlogz: 29.919 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16722it [50:39,  5.69it/s, batch: 0 | bound: 261 | nc: 25 | ncall: 452862 | eff(%):  3.688 | loglstar:   -inf < 72.103 <    inf | logz: 36.982 +/-  0.368 | dlogz: 28.166 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16764it [51:07,  5.69it/s, batch: 0 | bound: 263 | nc: 25 | ncall: 456697 | eff(%):  3.667 | loglstar:   -inf < 72.706 <    inf | logz: 37.466 +/-  0.369 | dlogz: 27.598 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17136it [52:36,  5.73it/s, batch: 0 | bound: 269 | nc: 25 | ncall: 469134 | eff(%):  3.649 | loglstar:   -inf < 77.370 <    inf | logz: 41.522 +/-  0.372 | dlogz: 24.960 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17166it [52:56,  5.68it/s, batch: 0 | bound: 271 | nc: 25 | ncall: 471900 | eff(%):  3.634 | loglstar:   -inf < 77.647 <    inf | logz: 41.815 +/-  0.373 | dlogz: 24.607 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17265it [53:50,  5.61it/s, batch: 0 | bound: 274 | nc: 25 | ncall: 479606 | eff(%):  3.596 | loglstar:   -inf < 78.630 <    inf | logz: 42.700 +/-  0.373 | dlogz: 23.524 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17400it [54:34,  5.40it/s, batch: 0 | bound: 277 | nc: 25 | ncall: 485719 | eff(%):  3.579 | loglstar:   -inf < 80.109 <    inf | logz: 43.884 +/-  0.374 | dlogz: 22.070 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17488it [55:21,  5.73it/s, batch: 0 | bound: 280 | nc: 25 | ncall: 492350 | eff(%):  3.548 | loglstar:   -inf < 80.898 <    inf | logz: 44.597 +/-  0.375 | dlogz: 21.180 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17592it [56:02,  5.61it/s, batch: 0 | bound: 283 | nc: 25 | ncall: 498049 | eff(%):  3.529 | loglstar:   -inf < 81.915 <    inf | logz: 45.414 +/-  0.376 | dlogz: 20.155 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17692it [56:43,  5.57it/s, batch: 0 | bound: 286 | nc: 25 | ncall: 503792 | eff(%):  3.508 | loglstar:   -inf < 82.735 <    inf | logz: 46.139 +/-  0.376 | dlogz: 19.229 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17840it [57:29,  5.67it/s, batch: 0 | bound: 289 | nc: 25 | ncall: 510243 | eff(%):  3.493 | loglstar:   -inf < 84.116 <    inf | logz: 47.184 +/-  0.377 | dlogz: 20.758 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18056it [58:29,  5.69it/s, batch: 0 | bound: 293 | nc: 25 | ncall: 518644 | eff(%):  3.478 | loglstar:   -inf < 85.908 <    inf | logz: 48.690 +/-  0.379 | dlogz: 24.678 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18197it [59:15,  5.78it/s, batch: 0 | bound: 296 | nc: 25 | ncall: 525147 | eff(%):  3.462 | loglstar:   -inf < 86.963 <    inf | logz: 49.539 +/-  0.380 | dlogz: 23.546 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18236it [59:41,  5.46it/s, batch: 0 | bound: 298 | nc: 25 | ncall: 528710 | eff(%):  3.446 | loglstar:   -inf < 87.245 <    inf | logz: 49.767 +/-  0.381 | dlogz: 23.240 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18308it [1:00:13,  5.75it/s, batch: 0 | bound: 300 | nc: 25 | ncall: 533274 | eff(%):  3.430 | loglstar:   -inf < 87.781 <    inf | logz: 50.168 +/-  0.381 | dlogz: 22.696 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18438it [1:00:58,  5.53it/s, batch: 0 | bound: 303 | nc: 25 | ncall: 539542 | eff(%):  3.414 | loglstar:   -inf < 88.657 <    inf | logz: 50.860 +/-  0.382 | dlogz: 21.744 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18659it [1:02:05,  5.36it/s, batch: 0 | bound: 307 | nc: 25 | ncall: 548930 | eff(%):  3.396 | loglstar:   -inf < 90.155 <    inf | logz: 51.974 +/-  0.384 | dlogz: 20.188 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18789it [1:03:07,  5.28it/s, batch: 0 | bound: 310 | nc: 25 | ncall: 557542 | eff(%):  3.367 | loglstar:   -inf < 91.042 <    inf | logz: 52.624 +/-  0.385 | dlogz: 19.278 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18851it [1:03:43,  5.77it/s, batch: 0 | bound: 312 | nc: 25 | ncall: 562606 | eff(%):  3.348 | loglstar:   -inf < 91.469 <    inf | logz: 52.922 +/-  0.386 | dlogz: 18.856 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18963it [1:04:39,  5.77it/s, batch: 0 | bound: 315 | nc: 25 | ncall: 570436 | eff(%):  3.321 | loglstar:   -inf < 92.143 <    inf | logz: 53.438 +/-  0.386 | dlogz: 18.116 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 19099it [1:05:32,  5.56it/s, batch: 0 | bound: 318 | nc: 25 | ncall: 577885 | eff(%):  3.302 | loglstar:   -inf < 92.886 <    inf | logz: 54.001 +/-  0.387 | dlogz: 17.281 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 19142it [1:06:07,  5.75it/s, batch: 0 | bound: 320 | nc: 25 | ncall: 582765 | eff(%):  3.282 | loglstar:   -inf < 93.198 <    inf | logz: 54.183 +/-  0.388 | dlogz: 17.013 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20037it [1:09:16,  5.65it/s, batch: 0 | bound: 333 | nc: 25 | ncall: 609660 | eff(%):  3.284 | loglstar:   -inf < 98.133 <    inf | logz: 57.526 +/-  0.395 | dlogz: 11.881 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20183it [1:10:47,  5.67it/s, batch: 0 | bound: 336 | nc: 25 | ncall: 622598 | eff(%):  3.239 | loglstar:   -inf < 98.805 <    inf | logz: 58.014 +/-  0.396 | dlogz: 11.101 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20547it [1:12:22,  5.69it/s, batch: 0 | bound: 342 | nc: 25 | ncall: 636045 | eff(%):  3.228 | loglstar:   -inf < 100.290 <    inf | logz: 59.044 +/-  0.399 | dlogz:  9.343 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20608it [1:13:37,  5.74it/s, batch: 0 | bound: 344 | nc: 25 | ncall: 646665 | eff(%):  3.184 | loglstar:   -inf < 100.603 <    inf | logz: 59.195 +/-  0.399 | dlogz:  9.070 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20667it [1:14:25,  5.78it/s, batch: 0 | bound: 346 | nc: 25 | ncall: 653323 | eff(%):  3.161 | loglstar:   -inf < 100.861 <    inf | logz: 59.342 +/-  0.400 | dlogz:  9.351 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20844it [1:15:32,  5.62it/s, batch: 0 | bound: 350 | nc: 25 | ncall: 662701 | eff(%):  3.143 | loglstar:   -inf < 101.588 <    inf | logz: 59.779 +/-  0.401 | dlogz:  8.560 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 21054it [1:16:38,  5.72it/s, batch: 0 | bound: 354 | nc: 25 | ncall: 671852 | eff(%):  3.131 | loglstar:   -inf < 102.420 <    inf | logz: 60.255 +/-  0.402 | dlogz:  8.593 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 21424it [1:18:25,  5.67it/s, batch: 0 | bound: 360 | nc: 25 | ncall: 686981 | eff(%):  3.116 | loglstar:   -inf < 103.707 <    inf | logz: 61.004 +/-  0.405 | dlogz:  7.634 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 22091it [1:21:32,  5.45it/s, batch: 0 | bound: 370 | nc: 25 | ncall: 713464 | eff(%):  3.094 | loglstar:   -inf < 105.942 <    inf | logz: 62.130 +/-  0.409 | dlogz:  5.874 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 22430it [1:23:32,  5.54it/s, batch: 0 | bound: 376 | nc: 25 | ncall: 730381 | eff(%):  3.069 | loglstar:   -inf < 106.950 <    inf | logz: 62.588 +/-  0.411 | dlogz:  5.599 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 22797it [1:25:24,  5.83it/s, batch: 0 | bound: 382 | nc: 25 | ncall: 746200 | eff(%):  3.053 | loglstar:   -inf < 107.919 <    inf | logz: 63.010 +/-  0.414 | dlogz:  4.450 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 22936it [1:26:57,  5.86it/s, batch: 0 | bound: 385 | nc: 25 | ncall: 759515 | eff(%):  3.018 | loglstar:   -inf < 108.237 <    inf | logz: 63.149 +/-  0.414 | dlogz:  4.205 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 23521it [1:29:30,  5.89it/s, batch: 0 | bound: 394 | nc: 25 | ncall: 780924 | eff(%):  3.010 | loglstar:   -inf < 109.507 <    inf | logz: 63.633 +/-  0.417 | dlogz:  3.444 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 23887it [1:31:36,  5.65it/s, batch: 0 | bound: 400 | nc: 25 | ncall: 798928 | eff(%):  2.988 | loglstar:   -inf < 110.198 <    inf | logz: 63.841 +/-  0.419 | dlogz:  2.553 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 24332it [1:33:57,  5.69it/s, batch: 0 | bound: 407 | nc: 25 | ncall: 818949 | eff(%):  2.969 | loglstar:   -inf < 111.052 <    inf | logz: 64.044 +/-  0.420 | dlogz:  2.267 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 24538it [1:35:16,  5.68it/s, batch: 0 | bound: 411 | nc: 25 | ncall: 830177 | eff(%):  2.954 | loglstar:   -inf < 111.423 <    inf | logz: 64.122 +/-  0.421 | dlogz:  1.840 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 24975it [1:37:44,  5.90it/s, batch: 0 | bound: 418 | nc: 25 | ncall: 852445 | eff(%):  2.928 | loglstar:   -inf < 112.141 <    inf | logz: 64.256 +/-  0.422 | dlogz:  1.630 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 25629it [1:40:14,  5.61it/s, batch: 0 | bound: 428 | nc: 25 | ncall: 874345 | eff(%):  2.930 | loglstar:   -inf < 112.936 <    inf | logz: 64.386 +/-  0.424 | dlogz:  0.833 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 25760it [1:41:44,  5.68it/s, batch: 0 | bound: 431 | nc: 25 | ncall: 887262 | eff(%):  2.902 | loglstar:   -inf < 113.099 <    inf | logz: 64.404 +/-  0.424 | dlogz:  0.685 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 25879it [1:42:52,  5.46it/s, batch: 0 | bound: 434 | nc: 25 | ncall: 896814 | eff(%):  2.884 | loglstar:   -inf < 113.228 <    inf | logz: 64.418 +/-  0.424 | dlogz:  0.592 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 26312it [1:45:48,  5.60it/s, batch: 0 | bound: 441 | nc: 25 | ncall: 921523 | eff(%):  2.854 | loglstar:   -inf < 113.705 <    inf | logz: 64.456 +/-  0.425 | dlogz:  0.283 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 36968it [2:20:11,  4.40it/s, batch: 5 | bound: 557 | nc: 25 | ncall: 1186128 | eff(%):  3.117 | loglstar: 104.696 < 112.076 < 105.313 | logz: 64.473 +/-  0.418 | stop:  0.984]
# done
# Wall time: 2h 20min 12s

# %%
# print(gobjective.parameters,"\n++++++++++++++++++++++++++++++++++++++++++++++++++++")

[[print(param)] for param in gobjective.parameters]#varying_parameters()]

[[print(param)] for param in gobjective.varying_parameters()];
# Out:
# ________________________________________________________________________________
# Parameters:       ''
# ________________________________________________________________________________
# Parameters: 'instrument parameters'
# <Parameter:    'scale'    , value=0.5538 (fixed)  , bounds=[-inf, inf]>
# <Parameter:     'bkg'     , value=1.26212e-06          , bounds=[3.6e-07, 3.24e-06]>
# <Parameter:'dq - resolution', value=5 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Structure - d2o'
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter:'thickness_solution', value=11.2454          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=6.10072          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=2.2246          , bounds=[0, 20]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'upper_lipid_d2o'
# <Parameter:'bilayer - area_per_molecule', value=137.293 (fixed)  , bounds=[100, 200]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_d2o - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=331 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=1.01061          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_d2o - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=940.2 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=20.3645          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.10072          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.10072          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - water_vm', value=29.7 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - Waters Per Head', value=0.936945          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=0.766504          , bounds=[0, 10]>
# <Parameter:'bilayer - Waters Per Head', value=0.936945          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=0.766504          , bounds=[0, 10]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.964992          , bounds=[0.5, 1]>
# ________________________________________________________________________________
# Parameters: 'lower_lipid_d2o'
# <Parameter:'bilayer - area_per_molecule', value=137.293 (fixed)  , bounds=[100, 200]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_d2o - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=331 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=1.01061          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_d2o - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=940.2 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=20.3645          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.10072          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.10072          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - water_vm', value=29.7 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - Waters Per Head', value=0.936945          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=0.766504          , bounds=[0, 10]>
# <Parameter:'bilayer - Waters Per Head', value=0.936945          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=0.766504          , bounds=[0, 10]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.964992          , bounds=[0.5, 1]>
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter:'thickness_solution', value=11.2454          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=6.10072          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# ________________________________________________________________________________
# Parameters: 'instrument parameters'
# <Parameter:    'scale'    , value=0.5538 (fixed)  , bounds=[-inf, inf]>
# <Parameter:     'bkg'     , value=3.3872e-06          , bounds=[6.040000000000001e-07, 5.436e-06]>
# <Parameter:'dq - resolution', value=5 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Structure - protein matched water'
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'thickness_solution', value=11.2454          , bounds=[6, 25]>
# <Parameter:'Protein Matched Water - sld', value=1.78065          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=2.2246          , bounds=[0, 20]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'upper_lipid_pmw'
# <Parameter:'bilayer - area_per_molecule', value=137.293 (fixed)  , bounds=[100, 200]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_pmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=331 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=1.01061          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_pmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=940.2 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=20.3645          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=1.78065          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=1.78065          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - water_vm', value=29.7 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - Waters Per Head', value=0.936945          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=0.766504          , bounds=[0, 10]>
# <Parameter:'bilayer - Waters Per Head', value=0.936945          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=0.766504          , bounds=[0, 10]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.964992          , bounds=[0.5, 1]>
# ________________________________________________________________________________
# Parameters: 'lower_lipid_pmw'
# <Parameter:'bilayer - area_per_molecule', value=137.293 (fixed)  , bounds=[100, 200]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_pmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=331 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=1.01061          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_pmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=940.2 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=20.3645          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=1.78065          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=1.78065          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - water_vm', value=29.7 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - Waters Per Head', value=0.936945          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=0.766504          , bounds=[0, 10]>
# <Parameter:'bilayer - Waters Per Head', value=0.936945          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=0.766504          , bounds=[0, 10]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.964992          , bounds=[0.5, 1]>
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'thickness_solution', value=11.2454          , bounds=[6, 25]>
# <Parameter:'Protein Matched Water - sld', value=1.78065          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# ________________________________________________________________________________
# Parameters: 'instrument parameters'
# <Parameter:    'scale'    , value=0.5538 (fixed)  , bounds=[-inf, inf]>
# <Parameter:     'bkg'     , value=2.53258e-06          , bounds=[3.46e-07, 3.114e-06]>
# <Parameter:'dq - resolution', value=5 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Structure - ACMW'
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:     'ACMW'
# <Parameter:'thickness_solution', value=11.2454          , bounds=[6, 25]>
# <Parameter: 'ACMW - sld'  , value=0.460818          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=2.2246          , bounds=[0, 20]>
# <Parameter:'ACMW - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'upper_lipid_acmw'
# <Parameter:'bilayer - area_per_molecule', value=137.293 (fixed)  , bounds=[100, 200]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_acmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=331 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=1.01061          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_acmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=940.2 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=20.3645          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter: 'ACMW - sld'  , value=0.460818          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter: 'ACMW - sld'  , value=0.460818          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - water_vm', value=29.7 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - Waters Per Head', value=0.936945          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=0.766504          , bounds=[0, 10]>
# <Parameter:'bilayer - Waters Per Head', value=0.936945          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=0.766504          , bounds=[0, 10]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.964992          , bounds=[0.5, 1]>
# ________________________________________________________________________________
# Parameters: 'lower_lipid_acmw'
# <Parameter:'bilayer - area_per_molecule', value=137.293 (fixed)  , bounds=[100, 200]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_acmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=331 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=1.01061          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_acmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=940.2 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=20.3645          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter: 'ACMW - sld'  , value=0.460818          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter: 'ACMW - sld'  , value=0.460818          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - water_vm', value=29.7 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - Waters Per Head', value=0.936945          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=0.766504          , bounds=[0, 10]>
# <Parameter:'bilayer - Waters Per Head', value=0.936945          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=0.766504          , bounds=[0, 10]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.964992          , bounds=[0.5, 1]>
# ________________________________________________________________________________
# Parameters:     'ACMW'
# <Parameter:'thickness_solution', value=11.2454          , bounds=[6, 25]>
# <Parameter: 'ACMW - sld'  , value=0.460818          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# <Parameter:'ACMW - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:     'bkg'     , value=1.26212e-06          , bounds=[3.6e-07, 3.24e-06]>
# <Parameter:'thickness_solution', value=11.2454          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=6.10072          , bounds=[5.35, 6.35]>
# <Parameter:'rough_preceding_solution', value=2.2246          , bounds=[0, 20]>
# <Parameter:'bilayer - thickness_heads', value=1.01061          , bounds=[1, 30]>
# <Parameter:'bilayer - thickness_tails', value=20.3645          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=6.6107          , bounds=[0, 10]>
# <Parameter:'bilayer - Waters Per Head', value=0.936945          , bounds=[0, 20]>
# <Parameter:'bilayer - Waters Per Tail', value=0.766504          , bounds=[0, 10]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.964992          , bounds=[0.5, 1]>
# <Parameter:     'bkg'     , value=3.3872e-06          , bounds=[6.040000000000001e-07, 5.436e-06]>
# <Parameter:'Protein Matched Water - sld', value=1.78065          , bounds=[1.35, 3.35]>
# <Parameter:     'bkg'     , value=2.53258e-06          , bounds=[3.46e-07, 3.114e-06]>
# <Parameter: 'ACMW - sld'  , value=0.460818          , bounds=[-0.56, 1]>

# %%
if choose==2:
    print(res1)
else:
    print(res)
# [['bkg', nan],
#  ['thickness_solution', nan],
#  ['D2O - sld', nan],
#  ['rough_preceding_solution', nan],
#  ['bilayer - area_per_molecule', nan],
#  ['bilayer - thickness_heads', nan],
#  ['bilayer - thickness_tails', nan],
#  ['bilayer - rough_top', nan],
#  ['bilayer - Waters Per Head', nan],
#  ['bilayer - Waters Per Tail', nan],
#  ['bilayer - ratio protein to bilayer', nan],
#  ['bkg', nan],
#  ['Protein Matched Water - sld', nan],
#  ['bkg', nan],
#  ['ACMW - sld', nan]]
# Out:
#          niter: 36968
#          ncall: array([1, 1, 1, ..., 1, 1, 1])
#            eff: 3.116695668595632
#        samples: array([[ 1.19705121e-06,  1.17286088e+01,  5.48759556e+00, ...,
#          2.95762755e+00,  1.32309111e-06,  7.08264085e-01],
#        [ 9.45107418e-07,  1.03156420e+01,  5.61520512e+00, ...,
#          2.45800981e+00,  9.24258716e-07,  7.45127076e-01],
#        [ 1.18130922e-06,  2.46625191e+01,  5.55632154e+00, ...,
#          3.28381785e+00,  1.17074439e-06, -4.27411760e-01],
#        ...,
#        [ 9.37407528e-07,  1.12705360e+01,  6.09825990e+00, ...,
#          1.76948484e+00,  2.57230013e-06,  4.50778052e-01],
#        [ 1.14963603e-06,  1.13817498e+01,  6.09754287e+00, ...,
#          1.77351754e+00,  2.54350138e-06,  4.51089100e-01],
#        [ 9.61980605e-07,  1.13097608e+01,  6.10072747e+00, ...,
#          1.76637827e+00,  2.55455015e-06,  4.61943597e-01]])
#     samples_id: array([ 93, 296, 450, ...,  79,  70, 406], dtype=int64)
#  samples_batch: array([0, 0, 0, ..., 0, 0, 0])
#     samples_it: array([    0,     0,     0, ..., 27453, 27466, 27094])
#      samples_u: array([[0.29064278, 0.30150572, 0.13759556, ..., 0.80381377, 0.35299534,
#         0.8129898 ],
#        [0.2031623 , 0.22713905, 0.26520512, ..., 0.5540049 , 0.2089085 ,
#         0.83661992],
#        [0.28517681, 0.98223785, 0.20632154, ..., 0.96690893, 0.29795679,
#         0.08499246],
#        ...,
#        [0.20048873, 0.27739663, 0.7482599 , ..., 0.20974242, 0.80429918,
#         0.64793465],
#        [0.27417918, 0.28324999, 0.74754287, ..., 0.21175877, 0.79389501,
#         0.64813404],
#        [0.20902104, 0.27946109, 0.75072747, ..., 0.20818914, 0.79788662,
#         0.65509205]])
#      samples_n: array([500, 500, 500, ...,   3,   2,   1])
#          logwt: array([-1.63710229e+05, -1.56869353e+05, -1.56748269e+05, ...,
#         5.47109804e+01,  5.47983840e+01,  5.50320773e+01])
#           logl: array([-1.63703319e+05, -1.56862441e+05, -1.56741355e+05, ...,
#         1.16214948e+02,  1.16382336e+02,  1.16668875e+02])
#         logvol: array([-1.99800266e-03, -3.99600533e-03, -5.99400799e-03, ...,
#        -6.04051439e+01, -6.08106090e+01, -6.15037562e+01])
#           logz: array([-1.63710229e+05, -1.56869353e+05, -1.56748269e+05, ...,
#         6.44595030e+01,  6.44595667e+01,  6.44596472e+01])
#        logzerr: array([0.1661668 , 0.16619087, 0.16621487, ..., 0.41580088, 0.41614599,
#        0.41692235])
#    information: array([ 6.90975206,  6.91175353,  6.91375038, ..., 45.28869041,
#        45.28904446, 45.289511  ])
#    batch_nlive: array([500, 500, 500, 500, 500, 500])
#   batch_bounds: array([[        -inf,          inf],
#        [107.78289002, 111.62570208],
#        [106.80623678, 107.78505435],
#        [106.08494508, 106.80724787],
#        [105.30711462, 112.70556715],
#        [104.69565772, 105.31333443]])
#          bound: [<dynesty.bounding.UnitCube object at 0x0000025ABD7F4208>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD7F4320>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD7F4240>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD7F4A58>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD7F4390>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD7F4C88>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD7F45F8>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD80D940>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD80D2E8>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD7F4AC8>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD80DA20>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AADD43518>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD8272B0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD8270B8>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD827198>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD8279B0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD827B70>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD827E48>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD827898>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AACA4D860>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF869198>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AACA4DF98>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF869240>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF869978>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF8694A8>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF8696A0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD80D780>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7853C8>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF785AC8>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7859B0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7854E0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AADD4F860>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF869860>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7BA198>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7BADA0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7BAA58>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7BAFD0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7BA390>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AADC964E0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AADC967F0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AADC962E8>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AADFFD0F0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AADD4FE10>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AADFFDF28>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AADFFDDA0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7DA668>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AADFFD8D0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7DA5C0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7DA2E8>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7DA0F0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7AE668>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7DAE10>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7AE438>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7AEDD8>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7AEDA0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7BA550>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AB0C1BB38>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AB0C1B470>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AB0C1B978>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AB0C1B4A8>, <dynesty.bounding.MultiEllipsoid object at 0x0000025AAF7AE6A0>, <dynesty.bounding.MultiEllipsoid object at 0x0000025ABD688048>, <dynesty.bounding.Mul ...
#     bound_iter: array([  0,   0,   0, ..., 460, 460, 460])
#  samples_bound: array([  0,   0,   0, ..., 458, 458, 453])
#          scale: array([1.        , 1.        , 1.        , ..., 0.35481172, 0.35481172,
#        0.35481172])

# %%
print(structure_acmw.slabs())
print(structure_pmw.slabs())
print(structure_d2o.slabs())
# Out:
# [[ 0.          0.          0.          0.          0.        ]
#  [11.2454122   0.46081815  0.          2.22460343  0.        ]
#  [ 1.01060637  5.40597739  0.          6.6106997   0.        ]
#  [20.36454845 -0.19754588  0.          6.6106997   0.        ]
#  [20.36454845 -0.19754588  0.          6.6106997   0.        ]
#  [ 1.01060637  5.40597739  0.          6.6106997   0.        ]
#  [11.2454122   0.46081815  0.          6.6106997   0.        ]]
# [[ 0.          0.          0.          0.          0.        ]
#  [11.2454122   1.78064724  0.          2.22460343  0.        ]
#  [ 1.01060637  5.42153757  0.          6.6106997   0.        ]
#  [20.36454845 -0.19271836  0.          6.6106997   0.        ]
#  [20.36454845 -0.19271836  0.          6.6106997   0.        ]
#  [ 1.01060637  5.42153757  0.          6.6106997   0.        ]
#  [11.2454122   1.78064724  0.          6.6106997   0.        ]]
# [[ 0.          0.          0.          0.          0.        ]
#  [11.2454122   6.10072478  0.          2.22460343  0.        ]
#  [ 1.01060637  5.47246934  0.          6.6106997   0.        ]
#  [20.36454845 -0.17691688  0.          6.6106997   0.        ]
#  [20.36454845 -0.17691688  0.          6.6106997   0.        ]
#  [ 1.01060637  5.47246934  0.          6.6106997   0.        ]
#  [11.2454122   6.10072478  0.          6.6106997   0.        ]]

# %%
# structure_d2o
# structure_pmw
plt.plot(*structure_d2o.sld_profile(),label="structure_d2o")
# structure_d2o.plot()
# plt.ylabel('SLD ($10^{-6} \AA^{-2})$')
# plt.xlabel('distance  $(\AA)$')

plt.plot(*structure_pmw.sld_profile(),label="structure_pmw")
# structure_pmw.plot()
plt.ylabel('SLD ($10^{-6} \AA^{-2})$')
plt.xlabel('distance  $(\AA)$')

plt.plot(*structure_acmw.sld_profile(),label="structure_acmw")
# structure_pmw.plot()
plt.ylabel('SLD ($10^{-6} \AA^{-2})$')
plt.xlabel('distance  $(\AA)$')
plt.legend()
plt.show();

# %%
if choose==1:
    gobjective.plot(samples=300)
else:
    gobjective.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
if choose==1:
    objective1.plot(samples=300)
else:
    objective1.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
if choose==1:
    objective2.plot(samples=300)
else:
    objective2.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
if choose==1:
    objective3.plot(samples=300)
else:
    objective3.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
print("model1: d2o", model1.scale, model1.bkg)
print("model2: pmw", model2.scale, model2.bkg)
print("model3: acmw", model3.scale, model3.bkg)
# Out:
# model1: d2o <Parameter:    'scale'    , value=0.5538 (fixed)  , bounds=[-inf, inf]> <Parameter:     'bkg'     , value=1.26212e-06          , bounds=[3.6e-07, 3.24e-06]>
# model2: pmw <Parameter:    'scale'    , value=0.5538 (fixed)  , bounds=[-inf, inf]> <Parameter:     'bkg'     , value=3.3872e-06          , bounds=[6.040000000000001e-07, 5.436e-06]>
# model3: acmw <Parameter:    'scale'    , value=0.5538 (fixed)  , bounds=[-inf, inf]> <Parameter:     'bkg'     , value=2.53258e-06          , bounds=[3.46e-07, 3.114e-06]>

# %%
# print(structure_d2o)

# %%
# print(structure_pmw)

# %%
# print(structure_acmw)

# %%
print(structure_d2o.slabs())
# Out:
# [[ 0.          0.          0.          0.          0.        ]
#  [11.2454122   6.10072478  0.          2.22460343  0.        ]
#  [ 1.01060637  5.47246934  0.          6.6106997   0.        ]
#  [20.36454845 -0.17691688  0.          6.6106997   0.        ]
#  [20.36454845 -0.17691688  0.          6.6106997   0.        ]
#  [ 1.01060637  5.47246934  0.          6.6106997   0.        ]
#  [11.2454122   6.10072478  0.          6.6106997   0.        ]]

# %%
print(structure_pmw.slabs())
# Out:
# [[ 0.          0.          0.          0.          0.        ]
#  [11.2454122   1.78064724  0.          2.22460343  0.        ]
#  [ 1.01060637  5.42153757  0.          6.6106997   0.        ]
#  [20.36454845 -0.19271836  0.          6.6106997   0.        ]
#  [20.36454845 -0.19271836  0.          6.6106997   0.        ]
#  [ 1.01060637  5.42153757  0.          6.6106997   0.        ]
#  [11.2454122   1.78064724  0.          6.6106997   0.        ]]

# %%
print(structure_acmw.slabs())
# Out:
# [[ 0.          0.          0.          0.          0.        ]
#  [11.2454122   0.46081815  0.          2.22460343  0.        ]
#  [ 1.01060637  5.40597739  0.          6.6106997   0.        ]
#  [20.36454845 -0.19754588  0.          6.6106997   0.        ]
#  [20.36454845 -0.19754588  0.          6.6106997   0.        ]
#  [ 1.01060637  5.40597739  0.          6.6106997   0.        ]
#  [11.2454122   0.46081815  0.          6.6106997   0.        ]]

# %%
if choose==2:
    # span = [(0,5000),(0,1.5),(0,0.4),(-10**3,10**3)] #span=span
    fig, axes = dyplot.runplot(res1, color='black', mark_final_live=False,
                               logplot=False)

# %%
if choose==2:
    print("max(-ln(X)) =", -min(res1["logvol"])) # -min(res1["logvol"] = max(-ln(X))
    print("max(logz), evidence =", max(res1["logz"]))
# Out:
# max(-ln(X)) = 61.503756167801576
# max(logz), evidence = 64.4596471881126

# %%
#gobjective.varying_parameters()
print("logp:",gobjective.logp())
print("logpost:",gobjective.logpost())
print("model1: d2o", model1.scale, model1.bkg)
print("model2: pmw", model2.scale, model2.bkg)
print("model3: acmw", model3.scale, model3.bkg)
print()
[[print(i,param.name+":",param.value, param.bounds)] for i,param in enumerate(gobjective.varying_parameters())];
print()
print(list(f_unique(p for p in flatten(gobjective.parameters) if "area" in p.name)))
# Out:
# logp: -22.090031695490907
# logpost: 85.34301234168517
# model1: d2o <Parameter:    'scale'    , value=0.5538 (fixed)  , bounds=[-inf, inf]> <Parameter:     'bkg'     , value=1.26212e-06          , bounds=[3.6e-07, 3.24e-06]>
# model2: pmw <Parameter:    'scale'    , value=0.5538 (fixed)  , bounds=[-inf, inf]> <Parameter:     'bkg'     , value=3.3872e-06          , bounds=[6.040000000000001e-07, 5.436e-06]>
# model3: acmw <Parameter:    'scale'    , value=0.5538 (fixed)  , bounds=[-inf, inf]> <Parameter:     'bkg'     , value=2.53258e-06          , bounds=[3.46e-07, 3.114e-06]>
#
# 0 bkg: 1.2621150246208263e-06 [3.6e-07, 3.24e-06]
# 1 thickness_solution: 11.245412198855554 [6, 25]
# 2 D2O - sld: 6.100724775520063 [5.35, 6.35]
# 3 rough_preceding_solution: 2.2246034313523246 [0, 20]
# 4 bilayer - thickness_heads: 1.010606367119147 [1, 30]
# 5 bilayer - thickness_tails: 20.364548446087838 [1, 30]
# 6 bilayer - roughs: 6.610699702441979 [0, 10]
# 7 bilayer - Waters Per Head: 0.9369448658004178 [0, 20]
# 8 bilayer - Waters Per Tail: 0.7665041402739893 [0, 10]
# 9 bilayer - ratio protein to bilayer: 0.9649923884713922 [0.5, 1]
# 10 bkg: 3.3871991373337323e-06 [6.040000000000001e-07, 5.436e-06]
# 11 Protein Matched Water - sld: 1.780647238866761 [1.35, 3.35]
# 12 bkg: 2.53257719841275e-06 [3.46e-07, 3.114e-06]
# 13 ACMW - sld: 0.460818152037912 [-0.56, 1]
#
# [Parameter(value=137.29326827582895, name='bilayer - area_per_molecule', vary=False, bounds=Interval(lb=100, ub=200), constraint=None)]

# %%
print(upper_lipid_d2o.total_vm(),"\n",
upper_lipid_d2o.sld_r(),"\n",
float(upper_lipid_d2o.b_heads_real) / float(upper_lipid_d2o.vm_heads.value) * 1.e6,"\n",
float(upper_lipid_d2o.b_tails_real) / float(upper_lipid_d2o.vm_tails.value) * 1.e6,"\n",
upper_lipid_d2o.b_heads_real,"\n",
upper_lipid_d2o.b_tails_real,"\n",
upper_lipid_d2o.protien_frac_in_head(),"\n",
upper_lipid_d2o.protien_frac_in_tail(),"\n",
upper_lipid_d2o.vm_head(),"\n",
upper_lipid_d2o.vm_tail(),"\n",
upper_lipid_d2o.vm_heads,"\n",
upper_lipid_d2o.vm_tails,"\n",
upper_lipid_d2o.PLRatio,"\n",
upper_lipid_d2o.vm_mscl,"\n",
upper_lipid_d2o.total_vm(),"\n")
# Out:
# 5869.329728414006
#  (1.9088905118003785, -0.19894885029381731)
#  1.9011329305135953
#  -0.28317379281004046
#  <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
#  <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
#  0.023639743804211594
#  0.47636025619578837
#  397.77227902034326
#  2486.30014970625
#  <Parameter:'bilayer - volume_heads', value=331 (fixed)  , bounds=[-inf, inf]>
#  <Parameter:'bilayer - volume_tails', value=940.2 (fixed)  , bounds=[-inf, inf]>
#  <Parameter:'bilayer - ratio protein to bilayer', value=0.964992          , bounds=[0.5, 1]>
#  <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
#  5869.329728414006

# %% [markdown]
# <!-- I believe correct values, leaflet roughness between head and tail is the same as the roughness preceeding the leaflet\
# class used is a modified version of the LipidLeaflet class native to refnx, its in the file\
# "protein" and called "LipidLeafletWithProtien"\
# volumes of head and tails are indirectly varied by changes in waters per head/tail\
# so the tails do not change volume\
# 0 scale: 0.5521883304658243 [0.5, 0.6]\
# 1 bkg: 3.8668280301251303e-07 [3.6e-07, 3.24e-06]\
# 2 thickness_solution: 10.788185214150985 [6, 25]\
# 3 D2O - sld: 6.120774383877097 [5.35, 6.35]\
# 4 rough_preceding_solution: 3.939327435493368 [0, 20]\
# 5 bilayer - area_per_molecule: 149.83843268748353 [60, 150]\
# 6 bilayer - thickness_heads: 2.2131024442953855 [1, 30]\
# 7 bilayer - thickness_tails: 19.19114563662231 [1, 30]\
# 8 bilayer - rough_top: 0.15555337800548585 [0, 10]\
# 9 bilayer - Waters Per Head: 0.017922237590786594 [0, 20]\
# 10 bilayer - Waters Per Tail: 0.02927203409960022 [0, 10]\
# 11 bilayer - ratio protein to bilayer: 0.7498017765068212 [0.25, 0.75]\
# 12 Protrusion - protrusion thickness: 6.090177488208205 [5, 100]\
# 13 Protrusion - protrusion roughness: 7.445463122283828 [0, 20]\
# 14 Protrusion - protrusion volfrac: 0.9963095809664922 [0, 1]\
# 15 scale: 0.5990025735918081 [0.5, 0.6]\
# 16 bkg: 3.5880504074107574e-06 [6.040000000000001e-07, 5.436e-06]\
# 17 Protein Matched Water - sld: 1.757984633375042 [1.35, 3.35]\
# 18 scale: 0.5907367476195101 [0.5, 0.6]\
# 19 bkg: 2.831535701386751e-06 [3.46e-07, 3.114e-06]\
# 20 ACMW - sld: 0.4132210895757328 [-0.56, 1] -->

# %%
if choose==2:
    labels = [param.name for param in gobjective.varying_parameters()]

    fig, axes = dyplot.traceplot(res1, labels = labels, #truths=np.zeros(fitter.nDim()),
                                 show_titles=True, trace_cmap='plasma',
                                 quantiles=[0.025, 0.5, 0.975])
    fig.tight_layout()

# %%
if choose==2:
    labels = [param.name for param in gobjective.varying_parameters()]

    fig, axes = dyplot.cornerpoints(res1, labels = labels#, #truths=np.zeros(fitter.nDim()),
                                 #show_titles=True,
                                 #trace_cmap='plasma',
                                 #quantiles=[0.025, 0.5, 0.975]
                                   )
    fig.tight_layout()
