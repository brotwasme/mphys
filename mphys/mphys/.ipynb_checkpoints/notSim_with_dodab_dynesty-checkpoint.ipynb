# %%
import os.path
import numpy as np
import matplotlib.pyplot as plt
import scipy
import refnx
from refnx.dataset import ReflectDataset, Data1D
from refnx.analysis import Transform, CurveFitter, Objective, Model, Parameter, GlobalObjective
from refnx.reflect import SLD, Slab, ReflectModel, LipidLeaflet
# from sepObjectiveGO import getObjective as gO
from dynesty import DynamicNestedSampler
from dynesty import plotting as dyplot
from CFitter import CFitter
# import make_sim_data as msd
# import lipidBilayerAsGiven.SLD_maker 
import data_in as di
import lipidBilayerAsGiven.Bilayer as bl
import lipidBilayerAsGiven.Popg as Pg
import lipidBilayerAsGiven.Popc as Pc
import lipidBilayerAsGiven.Dodab as ml

print('refnx: %s\nscipy: %s\nnumpy: %s' % (refnx.version.version,
                   scipy.version.version, np.version.version))
# %matplotlib inline
SEED = 12345
# Out:
# refnx: 0.1.9
# scipy: 1.3.0
# numpy: 1.16.4

# %%
dataD2o = Data1D(data=di.data_in("lipidBilayerData/54696_97_edit.txt"))
dataD2o.name="d2o"
dataPmw = Data1D(data=di.data_in("lipidBilayerData/54699_00_edit.txt"))
dataPmw.name="pmw"

plt.errorbar(dataD2o.data[0],dataD2o.data[1],dataD2o.data[2])
plt.errorbar(dataPmw.data[0],dataPmw.data[1],dataPmw.data[2])
plt.yscale("log")
plt.show()
# Out:
# csv
# cvs-collecting
# csv
# cvs-collecting

# %%
name = "bilayer"

d2o = SLD(6.07, "D2O")
pmw = SLD(2.35, "Protein Matched Water")
air = SLD(0.00, "Air")

d2o.real.setp(vary=True, bounds=(5.35, 6.35))
pmw.real.setp(vary=True, bounds=(1.35, 3.35))


apm = Parameter(value=62, name='%s - area_per_molecule' % name,
                bounds=(60, 150), vary=True)

#Define all the neutron b's
bc = 0.6646e-4  #Carbon
bo = 0.5804e-4  #Oxygen
bh = -0.3739e-4 #Hydrogen
bp = 0.513e-4   #Phosphorus
bn = 0.936e-4   #Nitrogen
bd = 0.6671e-4  #Deuterium

#Formulae of the molecule sections...
CH2 = (1*bc) + (2*bh)
CH = (1*bc) + (1*bh)
CH3 = (1*bc) + (3*bh)
D2O = (2*bd) + (1*bo)
H2O = (2*bh) + (1*bo)

# Calculate mole fraction of D2O from the bulk SLD..
# d2o_molfr = (1/D2O-H2O)*(contrast*27.64)-H2O
# wMol = (d2o_molfr * D2O) + ((1-d2o_molfr)*H2O)

#sum b's of all the different fragments
b_tails = Parameter(value=(28*CH2) + (2*CH) + (2*CH3),
                       name='%s - b_tails_real' % name)

sum_popc_heads = (8*bo) + (1*bp) + (1*bn) + (2*bc) + (4*CH2) + (3*CH3) + (1*CH)
sum_popg_heads = (10*bo) + (1*bp) + (2*bc) + (4*CH2) + (2*CH) + (2*bh)
b_heads = Parameter(value=(3*(sum_popc_heads) + (sum_popg_heads))/4,
                        name='%s - b_heads_real' % name)

#monolayer compositions
#sum_m_tails = (34*CH2) + (2*CH3);
#sum_m_heads = (1*bn) + (2*CH3) + (Waters_per_headD * wMol);

#volumes of each fragment
vCH2 = 27.7
nCH2 = 30
vCH3 = 54.6
vm_tails = Parameter(value=(nCH2 * vCH2) + (2 * vCH3),
            name='%s - volume_tails' % name) #
vm_heads = Parameter(value=331,
            name='%s - volume_heads' % name)  #

#thickness
thickness_tails = Parameter(value=vm_tails.value/apm.value,
            name='%s - thickness_tails' % name,
            bounds=((1-0.75)*vm_tails.value/apm.value,
                    (1+0.75)*vm_tails.value/apm.value),
               vary=True)
thickness_heads = Parameter(value=vm_heads.value/apm.value,
            name='%s - thickness_heads' % name,
            bounds=((1-0.75)*vm_heads.value/apm.value,
                    (1+0.75)*vm_heads.value/apm.value),
               vary=True)

rough_top = Parameter(value=12.0,
            name='%s - rough_top' % name,
            bounds=(0,20), vary=True)
rough_bot = Parameter(value=10.3,
            name='%s - rough_bot' % name,
            bounds=(0,15), vary=True)

# %%
# apm, b_heads, vm_heads, thickness_heads
# b_tails, vm_tails, thickness_tails, rough_head_tail
# rough_preceding_mono, head_solvent


head_solvent_d2o = SLD(6.07, "D2O in bilayer")
head_solvent_d2o.real.setp(6.07, vary=True, bounds=(5.35, 6.35))
upper_lipid_d2o = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
b_tails, vm_tails, thickness_tails, rough_top,
rough_top, head_solvent_d2o, reverse_monolayer=False)

lower_lipid_d2o = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
b_tails, vm_tails, thickness_tails, rough_top,
rough_top, head_solvent_d2o, reverse_monolayer=True)


head_solvent_pmw = SLD(2.35, "Protein Matched Water in bilayer")
head_solvent_pmw.real.setp(2.34, vary=True, bounds=(1.35, 3.35))
upper_lipid_pmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
b_tails, vm_tails, thickness_tails, rough_bot,
rough_bot, head_solvent_pmw, reverse_monolayer=False)

lower_lipid_pmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
b_tails, vm_tails, thickness_tails, rough_bot,
rough_bot, head_solvent_pmw, reverse_monolayer=True)

# %%
name_m = "mono, dodab"
APMD = Parameter(value=48, name='%s - area_per_molecule' % name_m,
        bounds=(30,120), vary=True)

# monolayer compositions
m_tails = Parameter(value=(34*CH2) + (2*CH3),
            name='%s - b_tails_real' % name_m)
m_heads = Parameter(value=(1*bn) + (2*CH3),
            name='%s - b_heads_real' % name_m)

# monolayer volumes
vm_m_tails = Parameter(value=vCH2*36,
            name='%s - volume_tails' % name)
vm_m_heads = Parameter(value=54.6,
            name='%s - volume_heads' % name)

# monolayer thicknesses
tail_thick_m = Parameter(value=vm_m_tails.value / APMD.value,
            name='%s - thickness_tails' % name,
            bounds=((1-0.75)*vm_m_tails.value / APMD.value,
                    (1+0.75)*vm_m_tails.value / APMD.value),
               vary=True)
head_thick_m = Parameter(value=vm_m_heads.value / APMD.value,
            name='%s - thickness heads' % name,
            bounds=((1-0.75)*vm_m_heads.value / APMD.value,
                    (1+0.75)*vm_m_heads.value / APMD.value),
               vary=True)

roughness_m =  Parameter(value=5.8,
            name='%s - roughness' % name,
            bounds=(0,10), vary=True)

# %%
m_head_solvent_pmw=SLD(2.35, "mono, dodab - Protein Matched Water in head")
m_head_solvent_pmw.real.setp(2.34, vary=True, bounds=(1.35, 3.35))
m_air_in_tail=SLD(0, "mono, dodab - air in tail")

dodab_pmw = LipidLeaflet(apm=APMD, b_heads=m_heads, vm_heads=vm_m_heads,
thickness_heads=head_thick_m, b_tails=m_tails, vm_tails=vm_m_tails,
thickness_tails=tail_thick_m, rough_head_tail=roughness_m,
rough_preceding_mono=roughness_m, head_solvent=m_head_solvent_pmw, tail_solvent=m_air_in_tail) #mono

m_head_solvent_d2o=SLD(6.07, "mono, dodab - D2O in head")
m_head_solvent_d2o.real.setp(6.07, vary=True, bounds=(5.35, 6.35))
dodab_d2o = LipidLeaflet(apm=APMD, b_heads=m_heads, vm_heads=vm_m_heads,
thickness_heads=head_thick_m, b_tails=m_tails, vm_tails=vm_m_tails,
thickness_tails=tail_thick_m, rough_head_tail=roughness_m,
rough_preceding_mono=roughness_m, head_solvent=m_head_solvent_d2o, tail_solvent=m_air_in_tail) #mono

# %%
structure_d2o = air(0, 0) | dodab_d2o | d2o(0, 0) | upper_lipid_d2o | lower_lipid_d2o | d2o(0, 0)
structure_pmw = air(0, 0) | dodab_pmw | pmw(0, 0) | upper_lipid_pmw | lower_lipid_pmw | pmw(0, 0)


solution_thickness = Parameter(value=14.3, bounds=(6, 20), vary=True,
            name='%s - thickness_solution' % name)

rough_preceding_solution = Parameter(value=4.6, bounds=(0, 20), vary=True,
            name='%s - rough_preceding_solution' % name)

structure_d2o[2].thick=solution_thickness#.setp(14.3, vary=True, bounds=(6, 20))
structure_d2o[2].rough=rough_preceding_solution#.setp(4.6, vary=True, bounds=(3, 20))
structure_pmw[2].thick=solution_thickness
structure_pmw[2].rough=rough_preceding_solution

structure_d2o[5].thick=solution_thickness
structure_d2o[5].rough=rough_preceding_solution
structure_pmw[5].thick=solution_thickness
structure_pmw[5].rough=rough_preceding_solution

# structure_d2o
# structure_pmw

plt.plot(*structure_d2o.sld_profile(),label=structure_d2o)
plt.ylabel('SLD /$10^{-6} \AA^{-2}$')
plt.xlabel('distance / $\AA$')
plt.plot(*structure_pmw.sld_profile(),label=structure_pmw)
plt.ylabel('SLD /$10^{-6} \AA^{-2}$')
plt.xlabel('distance / $\AA$')
plt.show();
# print(structure_d2o)
print(structure_pmw)
# Out:
# ________________________________________________________________________________
# Structure:
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# LipidLeaflet(Parameter(value=48.0, name='mono, dodab - area_per_molecule', vary=True, bounds=Interval(lb=30, ub=120), constraint=None), SLD([Parameter(value=2.1799999999999825e-06, name='mono, dodab - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=54.6, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=1.1375, name='bilayer - thickness heads', vary=True, bounds=Interval(lb=0.284375, ub=1.9906249999999999), constraint=None), SLD([Parameter(value=-0.00037430000000000005, name='mono, dodab - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=997.1999999999999, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=20.775, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=5.19375, ub=36.356249999999996), constraint=None), Parameter(value=5.8, name='bilayer - roughness', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=5.8, name='bilayer - roughness', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=2.34, name='mono, dodab - Protein Matched Water in head - sld', vary=True, bounds=Interval(lb=1.35, ub=3.35), constraint=None), Parameter(value=0.0, name='mono, dodab - Protein Matched Water in head - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=0.0, name='mono, dodab - air in tail - sld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='mono, dodab - air in tail - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=False, name='')
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'Protein Matched Water - thick', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Protein Matched Water - rough', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# LipidLeaflet(Parameter(value=62.0, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=60, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=5.338709677419355, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=1.3346774193548387, ub=9.34274193548387), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=15.16451612903226, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3.791129032258065, ub=26.537903225806453), constraint=None), Parameter(value=10.3, name='bilayer - rough_bot', vary=True, bounds=Interval(lb=0, ub=15), constraint=None), Parameter(value=10.3, name='bilayer - rough_bot', vary=True, bounds=Interval(lb=0, ub=15), constraint=None), head_solvent=SLD([Parameter(value=2.34, name='Protein Matched Water in bilayer - sld', vary=True, bounds=Interval(lb=1.35, ub=3.35), constraint=None), Parameter(value=0.0, name='Protein Matched Water in bilayer - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=None, reverse_monolayer=False, name='')
# LipidLeaflet(Parameter(value=62.0, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=60, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=5.338709677419355, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=1.3346774193548387, ub=9.34274193548387), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=15.16451612903226, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3.791129032258065, ub=26.537903225806453), constraint=None), Parameter(value=10.3, name='bilayer - rough_bot', vary=True, bounds=Interval(lb=0, ub=15), constraint=None), Parameter(value=10.3, name='bilayer - rough_bot', vary=True, bounds=Interval(lb=0, ub=15), constraint=None), head_solvent=SLD([Parameter(value=2.34, name='Protein Matched Water in bilayer - sld', vary=True, bounds=Interval(lb=1.35, ub=3.35), constraint=None), Parameter(value=0.0, name='Protein Matched Water in bilayer - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=None, reverse_monolayer=True, name='')
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'Protein Matched Water - thick', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Protein Matched Water - rough', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>

# %%
model1 = ReflectModel(structure_d2o)
model1.scale.setp(0.75, vary=True, bounds=(0.5, 1.5))
model1.bkg.setp(dataD2o.y.min(),vary=True,bounds=(dataD2o.y.min() * 0.2, dataD2o.y.min() * 1.8))

model2 = ReflectModel(structure_pmw)
model2.scale.setp(0.75, vary=True, bounds=(0.5, 1.5))
model2.bkg.setp(dataPmw.y.min(),vary=True,bounds=(dataPmw.y.min() * 0.2, dataPmw.y.min() * 1.8))

objective1 = Objective(model1, dataD2o, transform=Transform("logY"))
objective2 = Objective(model2, dataPmw, transform=Transform("logY"))
gobjective = GlobalObjective([objective1,objective2])

# if True:
#     fitter = CurveFitter(gobjective)
#     fitter.fit("differential_evolution", target="nlpost")#, seed=SEED)

fitter = CFitter(gobjective)
DynamicNestedSampler
DNSampler = DynamicNestedSampler(fitter.logl, fitter.priorTransform, fitter.nDim())
DNSampler.run_nested(dlogz_init=0.05) # was 0.01
res1 = DNSampler.results
# Out:
# 1784it [01:26,  3.79it/s, batch: 0 | bound: 1 | nc: 25 | ncall: 17415 | eff(%):  9.958 | loglstar:   -inf < -16717.688 <    inf | logz: -16728.161 +/-  0.205 | dlogz: 11922.546 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 11020it [38:24,  3.98it/s, batch: 0 | bound: 140 | nc: 25 | ncall: 248427 | eff(%):  4.427 | loglstar:   -inf < -593.457 <    inf | logz: -618.975 +/-  0.314 | dlogz: 175.173 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12313it [43:56,  4.12it/s, batch: 0 | bound: 159 | nc: 25 | ncall: 281125 | eff(%):  4.372 | loglstar:   -inf < -502.041 <    inf | logz: -529.959 +/-  0.328 | dlogz: 124.823 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12677it [45:30,  3.27it/s, batch: 0 | bound: 165 | nc: 34 | ncall: 290374 | eff(%):  4.358 | loglstar:   -inf < -481.870 <    inf | logz: -510.434 +/-  0.332 | dlogz: 104.567 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13350it [48:21,  7.81it/s, batch: 0 | bound: 175 | nc: 25 | ncall: 307643 | eff(%):  4.332 | loglstar:   -inf < -451.477 <    inf | logz: -480.977 +/-  0.337 | dlogz: 89.241 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13917it [49:56,  3.52it/s, batch: 0 | bound: 185 | nc: 25 | ncall: 322122 | eff(%):  4.314 | loglstar:   -inf < -430.324 <    inf | logz: -460.792 +/-  0.344 | dlogz: 68.846 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14078it [50:38,  4.13it/s, batch: 0 | bound: 187 | nc: 25 | ncall: 326367 | eff(%):  4.307 | loglstar:   -inf < -425.312 <    inf | logz: -456.022 +/-  0.345 | dlogz: 63.752 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14764it [52:09,  3.85it/s, batch: 0 | bound: 198 | nc: 116 | ncall: 343839 | eff(%):  4.288 | loglstar:   -inf < -405.172 <    inf | logz: -437.119 +/-  0.351 | dlogz: 46.677 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14932it [52:30,  8.32it/s, batch: 0 | bound: 200 | nc: 25 | ncall: 348205 | eff(%):  4.282 | loglstar:   -inf < -400.801 <    inf | logz: -433.065 +/-  0.353 | dlogz: 52.317 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15090it [52:51,  5.59it/s, batch: 0 | bound: 204 | nc: 61 | ncall: 352507 | eff(%):  4.275 | loglstar:   -inf < -397.101 <    inf | logz: -429.479 +/-  0.354 | dlogz: 48.411 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15256it [53:16,  8.17it/s, batch: 0 | bound: 206 | nc: 25 | ncall: 357689 | eff(%):  4.259 | loglstar:   -inf < -393.776 <    inf | logz: -426.475 +/-  0.355 | dlogz: 45.075 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15406it [53:52,  4.24it/s, batch: 0 | bound: 209 | nc: 25 | ncall: 362172 | eff(%):  4.248 | loglstar:   -inf < -390.327 <    inf | logz: -423.444 +/-  0.358 | dlogz: 41.835 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15580it [54:40,  4.36it/s, batch: 0 | bound: 212 | nc: 25 | ncall: 367189 | eff(%):  4.237 | loglstar:   -inf < -386.672 <    inf | logz: -419.983 +/-  0.359 | dlogz: 38.024 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15689it [55:13,  4.26it/s, batch: 0 | bound: 214 | nc: 25 | ncall: 370711 | eff(%):  4.226 | loglstar:   -inf < -384.316 <    inf | logz: -417.912 +/-  0.360 | dlogz: 36.470 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15807it [55:45,  4.22it/s, batch: 0 | bound: 216 | nc: 25 | ncall: 374008 | eff(%):  4.221 | loglstar:   -inf < -381.990 <    inf | logz: -415.699 +/-  0.361 | dlogz: 34.019 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15937it [56:21,  3.94it/s, batch: 0 | bound: 218 | nc: 25 | ncall: 377604 | eff(%):  4.215 | loglstar:   -inf < -379.625 <    inf | logz: -413.522 +/-  0.362 | dlogz: 37.238 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 16127it [57:09,  4.23it/s, batch: 0 | bound: 221 | nc: 25 | ncall: 382538 | eff(%):  4.210 | loglstar:   -inf < -376.142 <    inf | logz: -410.375 +/-  0.364 | dlogz: 34.692 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 16305it [58:01,  4.12it/s, batch: 0 | bound: 224 | nc: 25 | ncall: 387936 | eff(%):  4.198 | loglstar:   -inf < -373.172 <    inf | logz: -407.705 +/-  0.366 | dlogz: 31.952 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 16420it [58:35,  4.09it/s, batch: 0 | bound: 226 | nc: 25 | ncall: 391396 | eff(%):  4.190 | loglstar:   -inf < -371.360 <    inf | logz: -406.071 +/-  0.367 | dlogz: 33.864 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16575it [59:21,  1.20it/s, batch: 0 | bound: 231 | nc: 90 | ncall: 397441 | eff(%):  4.165 | loglstar:   -inf < -369.176 <    inf | logz: -404.103 +/-  0.368 | dlogz: 31.586 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 16681it [59:50,  1.96it/s, batch: 0 | bound: 233 | nc: 62 | ncall: 400544 | eff(%):  4.159 | loglstar:   -inf < -367.576 <    inf | logz: -402.774 +/-  0.369 | dlogz: 30.045 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 16873it [1:00:41,  4.12it/s, batch: 0 | bound: 235 | nc: 25 | ncall: 405939 | eff(%):  4.151 | loglstar:   -inf < -364.578 <    inf | logz: -400.173 +/-  0.371 | dlogz: 27.060 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 17069it [1:01:08,  8.15it/s, batch: 0 | bound: 238 | nc: 25 | ncall: 411323 | eff(%):  4.145 | loglstar:   -inf < -362.072 <    inf | logz: -397.898 +/-  0.372 | dlogz: 33.378 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 17239it [1:01:33,  8.22it/s, batch: 0 | bound: 241 | nc: 25 | ncall: 415913 | eff(%):  4.140 | loglstar:   -inf < -360.032 <    inf | logz: -396.129 +/-  0.373 | dlogz: 44.001 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 17364it [1:01:56,  7.97it/s, batch: 0 | bound: 244 | nc: 25 | ncall: 420457 | eff(%):  4.125 | loglstar:   -inf < -358.160 <    inf | logz: -394.653 +/-  0.376 | dlogz: 42.277 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 17523it [1:02:32,  8.00it/s, batch: 0 | bound: 247 | nc: 25 | ncall: 425312 | eff(%):  4.115 | loglstar:   -inf < -356.333 <    inf | logz: -392.901 +/-  0.377 | dlogz: 40.204 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 17692it [1:03:08,  4.44it/s, batch: 0 | bound: 250 | nc: 25 | ncall: 430396 | eff(%):  4.106 | loglstar:   -inf < -354.400 <    inf | logz: -391.335 +/-  0.378 | dlogz: 38.301 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 18395it [1:05:02,  7.92it/s, batch: 0 | bound: 260 | nc: 25 | ncall: 448939 | eff(%):  4.093 | loglstar:   -inf < -346.570 <    inf | logz: -384.891 +/-  0.385 | dlogz: 30.452 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 18637it [1:05:39,  8.13it/s, batch: 0 | bound: 264 | nc: 25 | ncall: 456209 | eff(%):  4.081 | loglstar:   -inf < -344.101 <    inf | logz: -382.775 +/-  0.387 | dlogz: 27.851 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 18773it [1:06:03,  8.19it/s, batch: 0 | bound: 267 | nc: 25 | ncall: 460810 | eff(%):  4.069 | loglstar:   -inf < -342.958 <    inf | logz: -381.727 +/-  0.388 | dlogz: 26.531 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 19170it [1:06:57,  7.99it/s, batch: 0 | bound: 273 | nc: 25 | ncall: 471795 | eff(%):  4.059 | loglstar:   -inf < -339.200 <    inf | logz: -378.791 +/-  0.391 | dlogz: 24.994 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 19396it [1:07:29,  7.76it/s, batch: 0 | bound: 277 | nc: 25 | ncall: 478298 | eff(%):  4.051 | loglstar:   -inf < -337.172 <    inf | logz: -377.145 +/-  0.394 | dlogz: 22.896 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 19525it [1:07:55,  7.92it/s, batch: 0 | bound: 280 | nc: 25 | ncall: 483293 | eff(%):  4.036 | loglstar:   -inf < -335.923 <    inf | logz: -376.240 +/-  0.395 | dlogz: 21.734 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 19730it [1:08:30,  8.45it/s, batch: 0 | bound: 284 | nc: 25 | ncall: 490205 | eff(%):  4.021 | loglstar:   -inf < -334.145 <    inf | logz: -374.782 +/-  0.397 | dlogz: 19.866 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 19846it [1:08:55,  8.55it/s, batch: 0 | bound: 287 | nc: 25 | ncall: 495068 | eff(%):  4.005 | loglstar:   -inf < -333.244 <    inf | logz: -374.031 +/-  0.398 | dlogz: 18.962 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 20144it [1:09:40,  8.72it/s, batch: 0 | bound: 292 | nc: 25 | ncall: 504235 | eff(%):  3.991 | loglstar:   -inf < -330.837 <    inf | logz: -372.171 +/-  0.400 | dlogz: 18.181 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 20186it [1:09:56,  7.80it/s, batch: 0 | bound: 294 | nc: 25 | ncall: 507358 | eff(%):  3.975 | loglstar:   -inf < -330.559 <    inf | logz: -371.925 +/-  0.400 | dlogz: 17.851 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 20323it [1:10:20,  8.19it/s, batch: 0 | bound: 297 | nc: 25 | ncall: 512244 | eff(%):  3.964 | loglstar:   -inf < -329.500 <    inf | logz: -371.157 +/-  0.402 | dlogz: 16.809 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 20726it [1:11:20,  8.44it/s, batch: 0 | bound: 304 | nc: 25 | ncall: 524410 | eff(%):  3.948 | loglstar:   -inf < -326.611 <    inf | logz: -368.973 +/-  0.405 | dlogz: 17.457 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 20926it [1:11:52,  8.04it/s, batch: 0 | bound: 308 | nc: 25 | ncall: 530735 | eff(%):  3.939 | loglstar:   -inf < -325.346 <    inf | logz: -368.026 +/-  0.406 | dlogz: 16.111 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 21018it [1:12:12,  8.48it/s, batch: 0 | bound: 311 | nc: 25 | ncall: 534646 | eff(%):  3.928 | loglstar:   -inf < -324.751 <    inf | logz: -367.583 +/-  0.407 | dlogz: 15.636 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 21194it [1:12:43,  8.48it/s, batch: 0 | bound: 315 | nc: 25 | ncall: 541117 | eff(%):  3.913 | loglstar:   -inf < -323.533 <    inf | logz: -366.789 +/-  0.409 | dlogz: 14.489 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 21421it [1:13:19,  8.40it/s, batch: 0 | bound: 319 | nc: 25 | ncall: 548291 | eff(%):  3.903 | loglstar:   -inf < -321.808 <    inf | logz: -365.572 +/-  0.411 | dlogz: 15.594 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 21637it [1:14:30,  4.47it/s, batch: 0 | bound: 323 | nc: 25 | ncall: 557690 | eff(%):  3.876 | loglstar:   -inf < -320.410 <    inf | logz: -364.522 +/-  0.413 | dlogz: 14.112 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 21975it [1:15:22,  8.40it/s, batch: 0 | bound: 329 | nc: 25 | ncall: 567742 | eff(%):  3.867 | loglstar:   -inf < -318.450 <    inf | logz: -363.032 +/-  0.416 | dlogz: 13.198 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 22153it [1:16:13,  4.52it/s, batch: 0 | bound: 333 | nc: 25 | ncall: 574115 | eff(%):  3.855 | loglstar:   -inf < -317.580 <    inf | logz: -362.387 +/-  0.417 | dlogz: 12.197 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 22305it [1:16:54,  4.53it/s, batch: 0 | bound: 336 | nc: 25 | ncall: 579741 | eff(%):  3.844 | loglstar:   -inf < -316.672 <    inf | logz: -361.841 +/-  0.418 | dlogz: 14.496 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 22391it [1:17:26,  8.08it/s, batch: 0 | bound: 339 | nc: 25 | ncall: 583780 | eff(%):  3.832 | loglstar:   -inf < -316.216 <    inf | logz: -361.527 +/-  0.419 | dlogz: 14.010 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 22608it [1:18:31,  3.85it/s, batch: 0 | bound: 343 | nc: 25 | ncall: 590882 | eff(%):  3.823 | loglstar:   -inf < -315.128 <    inf | logz: -360.800 +/-  0.420 | dlogz: 12.849 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 22981it [1:20:29,  4.23it/s, batch: 0 | bound: 349 | nc: 25 | ncall: 602976 | eff(%):  3.808 | loglstar:   -inf < -313.233 <    inf | logz: -359.594 +/-  0.423 | dlogz: 17.480 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 23466it [1:22:50,  4.46it/s, batch: 0 | bound: 357 | nc: 25 | ncall: 616576 | eff(%):  3.803 | loglstar:   -inf < -310.955 <    inf | logz: -358.167 +/-  0.427 | dlogz: 15.084 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 23907it [1:24:16,  4.47it/s, batch: 0 | bound: 364 | nc: 25 | ncall: 629240 | eff(%):  3.796 | loglstar:   -inf < -308.717 <    inf | logz: -356.914 +/-  0.431 | dlogz: 12.950 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 24051it [1:25:01,  4.36it/s, batch: 0 | bound: 367 | nc: 25 | ncall: 634380 | eff(%):  3.788 | loglstar:   -inf < -308.185 <    inf | logz: -356.506 +/-  0.432 | dlogz: 12.253 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 24359it [1:26:20,  4.41it/s, batch: 0 | bound: 372 | nc: 25 | ncall: 643332 | eff(%):  3.783 | loglstar:   -inf < -306.902 <    inf | logz: -355.749 +/-  0.434 | dlogz: 12.529 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 24519it [1:27:14,  3.96it/s, batch: 0 | bound: 375 | nc: 25 | ncall: 648633 | eff(%):  3.777 | loglstar:   -inf < -306.302 <    inf | logz: -355.377 +/-  0.435 | dlogz: 11.837 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 24667it [1:28:02,  4.32it/s, batch: 0 | bound: 378 | nc: 25 | ncall: 653507 | eff(%):  3.772 | loglstar:   -inf < -305.681 <    inf | logz: -355.052 +/-  0.436 | dlogz: 11.216 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 24788it [1:28:55,  4.43it/s, batch: 0 | bound: 381 | nc: 25 | ncall: 659078 | eff(%):  3.758 | loglstar:   -inf < -305.262 <    inf | logz: -354.794 +/-  0.437 | dlogz: 12.740 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 24994it [1:30:06,  4.20it/s, batch: 0 | bound: 385 | nc: 25 | ncall: 666426 | eff(%):  3.748 | loglstar:   -inf < -304.507 <    inf | logz: -354.385 +/-  0.439 | dlogz: 11.919 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 25150it [1:31:01,  4.23it/s, batch: 0 | bound: 388 | nc: 25 | ncall: 672020 | eff(%):  3.740 | loglstar:   -inf < -303.936 <    inf | logz: -354.100 +/-  0.440 | dlogz: 11.322 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 25328it [1:32:25,  4.19it/s, batch: 0 | bound: 392 | nc: 25 | ncall: 680726 | eff(%):  3.718 | loglstar:   -inf < -303.313 <    inf | logz: -353.784 +/-  0.441 | dlogz: 10.650 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 25627it [1:33:48,  4.22it/s, batch: 0 | bound: 397 | nc: 25 | ncall: 689146 | eff(%):  3.716 | loglstar:   -inf < -302.353 <    inf | logz: -353.310 +/-  0.443 | dlogz:  9.579 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 25734it [1:34:34,  4.00it/s, batch: 0 | bound: 400 | nc: 25 | ncall: 693794 | eff(%):  3.706 | loglstar:   -inf < -302.034 <    inf | logz: -353.148 +/-  0.443 | dlogz:  9.203 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 25922it [1:35:38,  4.24it/s, batch: 0 | bound: 404 | nc: 25 | ncall: 700378 | eff(%):  3.699 | loglstar:   -inf < -301.455 <    inf | logz: -352.879 +/-  0.444 | dlogz:  8.558 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 26087it [1:36:27,  4.29it/s, batch: 0 | bound: 407 | nc: 25 | ncall: 705534 | eff(%):  3.695 | loglstar:   -inf < -300.974 <    inf | logz: -352.660 +/-  0.445 | dlogz:  8.009 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 26222it [1:37:19,  4.18it/s, batch: 0 | bound: 410 | nc: 25 | ncall: 710793 | eff(%):  3.687 | loglstar:   -inf < -300.578 <    inf | logz: -352.490 +/-  0.446 | dlogz:  7.569 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 26673it [1:39:22,  4.30it/s, batch: 0 | bound: 417 | nc: 25 | ncall: 723817 | eff(%):  3.683 | loglstar:   -inf < -299.436 <    inf | logz: -351.987 +/-  0.449 | dlogz:  6.720 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 26818it [1:40:07,  4.16it/s, batch: 0 | bound: 420 | nc: 25 | ncall: 728268 | eff(%):  3.680 | loglstar:   -inf < -299.089 <    inf | logz: -351.855 +/-  0.449 | dlogz:  6.299 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 27002it [1:41:00,  4.39it/s, batch: 0 | bound: 423 | nc: 25 | ncall: 733797 | eff(%):  3.677 | loglstar:   -inf < -298.632 <    inf | logz: -351.698 +/-  0.450 | dlogz:  5.776 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 27176it [1:41:55,  4.34it/s, batch: 0 | bound: 426 | nc: 25 | ncall: 739386 | eff(%):  3.673 | loglstar:   -inf < -298.266 <    inf | logz: -351.562 +/-  0.451 | dlogz:  5.295 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 27536it [1:43:31,  8.46it/s, batch: 0 | bound: 432 | nc: 25 | ncall: 750309 | eff(%):  3.668 | loglstar:   -inf < -297.385 <    inf | logz: -351.310 +/-  0.453 | dlogz:  4.330 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 27676it [1:44:01,  4.41it/s, batch: 0 | bound: 435 | nc: 25 | ncall: 755440 | eff(%):  3.661 | loglstar:   -inf < -297.045 <    inf | logz: -351.217 +/-  0.453 | dlogz:  3.964 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 27748it [1:44:37,  8.48it/s, batch: 0 | bound: 437 | nc: 25 | ncall: 759550 | eff(%):  3.651 | loglstar:   -inf < -296.886 <    inf | logz: -351.171 +/-  0.454 | dlogz:  3.779 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 27976it [1:45:39,  3.39it/s, batch: 0 | bound: 441 | nc: 25 | ncall: 766986 | eff(%):  3.645 | loglstar:   -inf < -296.429 <    inf | logz: -351.037 +/-  0.455 | dlogz:  3.501 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 28047it [1:46:10,  4.36it/s, batch: 0 | bound: 443 | nc: 25 | ncall: 770658 | eff(%):  3.637 | loglstar:   -inf < -296.288 <    inf | logz: -350.999 +/-  0.455 | dlogz:  3.327 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 28094it [1:46:45,  4.37it/s, batch: 0 | bound: 445 | nc: 25 | ncall: 774130 | eff(%):  3.627 | loglstar:   -inf < -296.195 <    inf | logz: -350.975 +/-  0.455 | dlogz:  3.213 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 28400it [1:48:15,  4.20it/s, batch: 0 | bound: 450 | nc: 25 | ncall: 782732 | eff(%):  3.626 | loglstar:   -inf < -295.613 <    inf | logz: -350.829 +/-  0.457 | dlogz:  3.693 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 28552it [1:49:10,  4.13it/s, batch: 0 | bound: 453 | nc: 25 | ncall: 788308 | eff(%):  3.620 | loglstar:   -inf < -295.366 <    inf | logz: -350.767 +/-  0.457 | dlogz:  3.338 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 28702it [1:50:16,  4.03it/s, batch: 0 | bound: 456 | nc: 25 | ncall: 794914 | eff(%):  3.608 | loglstar:   -inf < -295.106 <    inf | logz: -350.712 +/-  0.458 | dlogz:  2.998 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 29337it [1:53:18,  4.07it/s, batch: 0 | bound: 466 | nc: 25 | ncall: 813383 | eff(%):  3.605 | loglstar:   -inf < -294.030 <    inf | logz: -350.529 +/-  0.460 | dlogz:  1.698 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 29471it [1:54:25,  4.29it/s, batch: 0 | bound: 469 | nc: 25 | ncall: 820121 | eff(%):  3.591 | loglstar:   -inf < -293.828 <    inf | logz: -350.498 +/-  0.460 | dlogz:  1.461 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 29598it [1:55:24,  6.27it/s, batch: 0 | bound: 472 | nc: 25 | ncall: 826097 | eff(%):  3.581 | loglstar:   -inf < -293.642 <    inf | logz: -350.472 +/-  0.460 | dlogz:  1.253 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 29657it [1:56:01,  4.27it/s, batch: 0 | bound: 474 | nc: 25 | ncall: 829979 | eff(%):  3.571 | loglstar:   -inf < -293.561 <    inf | logz: -350.461 +/-  0.460 | dlogz:  1.458 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 29760it [1:56:54,  4.29it/s, batch: 0 | bound: 477 | nc: 25 | ncall: 836307 | eff(%):  3.556 | loglstar:   -inf < -293.401 <    inf | logz: -350.442 +/-  0.461 | dlogz:  1.290 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 29829it [1:57:33,  4.37it/s, batch: 0 | bound: 479 | nc: 25 | ncall: 840194 | eff(%):  3.548 | loglstar:   -inf < -293.302 <    inf | logz: -350.430 +/-  0.461 | dlogz:  1.184 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 29884it [1:58:26,  4.22it/s, batch: 0 | bound: 481 | nc: 25 | ncall: 845715 | eff(%):  3.531 | loglstar:   -inf < -293.224 <    inf | logz: -350.421 +/-  0.461 | dlogz:  1.103 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 30031it [1:59:19,  6.51it/s, batch: 0 | bound: 484 | nc: 25 | ncall: 851110 | eff(%):  3.526 | loglstar:   -inf < -292.988 <    inf | logz: -350.398 +/-  0.461 | dlogz:  1.277 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 30118it [1:59:56,  4.51it/s, batch: 0 | bound: 487 | nc: 25 | ncall: 855694 | eff(%):  3.518 | loglstar:   -inf < -292.869 <    inf | logz: -350.385 +/-  0.461 | dlogz:  1.284 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 30215it [2:00:40,  4.33it/s, batch: 0 | bound: 490 | nc: 25 | ncall: 860237 | eff(%):  3.510 | loglstar:   -inf < -292.727 <    inf | logz: -350.372 +/-  0.462 | dlogz:  1.139 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 30352it [2:01:33,  4.40it/s, batch: 0 | bound: 493 | nc: 25 | ncall: 865731 | eff(%):  3.504 | loglstar:   -inf < -292.510 <    inf | logz: -350.355 +/-  0.462 | dlogz:  0.951 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 30417it [2:02:08,  4.40it/s, batch: 0 | bound: 495 | nc: 25 | ncall: 869369 | eff(%):  3.497 | loglstar:   -inf < -292.432 <    inf | logz: -350.347 +/-  0.462 | dlogz:  0.868 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 30420it [2:02:23,  2.51s/it, batch: 0 | bound: 496 | nc: 171 | ncall: 870729 | eff(%):  3.492 | loglstar:   -inf < -292.430 <    inf | logz: -350.347 +/-  0.462 | dlogz:  0.865 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 30684it [2:03:36,  4.15it/s, batch: 0 | bound: 500 | nc: 25 | ncall: 878580 | eff(%):  3.490 | loglstar:   -inf < -292.054 <    inf | logz: -350.319 +/-  0.462 | dlogz:  1.037 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 30791it [2:04:28,  4.19it/s, batch: 0 | bound: 503 | nc: 25 | ncall: 883757 | eff(%):  3.482 | loglstar:   -inf < -291.897 <    inf | logz: -350.309 +/-  0.463 | dlogz:  0.898 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 31015it [2:05:45,  4.11it/s, batch: 0 | bound: 507 | nc: 25 | ncall: 891361 | eff(%):  3.478 | loglstar:   -inf < -291.565 <    inf | logz: -350.291 +/-  0.463 | dlogz:  0.649 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 31295it [2:07:18,  4.05it/s, batch: 0 | bound: 512 | nc: 25 | ncall: 900743 | eff(%):  3.472 | loglstar:   -inf < -291.251 <    inf | logz: -350.271 +/-  0.463 | dlogz:  1.240 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 31394it [2:08:15,  4.21it/s, batch: 0 | bound: 515 | nc: 25 | ncall: 906429 | eff(%):  3.462 | loglstar:   -inf < -291.128 <    inf | logz: -350.266 +/-  0.463 | dlogz:  1.100 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 31844it [2:10:34,  4.22it/s, batch: 0 | bound: 522 | nc: 25 | ncall: 920643 | eff(%):  3.457 | loglstar:   -inf < -290.605 <    inf | logz: -350.245 +/-  0.464 | dlogz:  0.587 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 31961it [2:11:50,  4.12it/s, batch: 0 | bound: 525 | nc: 25 | ncall: 928265 | eff(%):  3.441 | loglstar:   -inf < -290.491 <    inf | logz: -350.241 +/-  0.464 | dlogz:  0.489 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 32401it [2:14:00,  4.12it/s, batch: 0 | bound: 532 | nc: 25 | ncall: 941488 | eff(%):  3.440 | loglstar:   -inf < -290.043 <    inf | logz: -350.230 +/-  0.464 | dlogz:  0.230 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 32495it [2:14:45,  4.27it/s, batch: 0 | bound: 535 | nc: 25 | ncall: 945929 | eff(%):  3.433 | loglstar:   -inf < -289.937 <    inf | logz: -350.228 +/-  0.464 | dlogz:  0.194 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 32641it [2:15:55,  4.25it/s, batch: 0 | bound: 538 | nc: 25 | ncall: 953029 | eff(%):  3.423 | loglstar:   -inf < -289.764 <    inf | logz: -350.225 +/-  0.464 | dlogz:  0.148 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 32851it [2:17:44,  4.22it/s, batch: 0 | bound: 542 | nc: 25 | ncall: 964008 | eff(%):  3.406 | loglstar:   -inf < -289.577 <    inf | logz: -350.222 +/-  0.464 | dlogz:  0.099 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 32919it [2:18:46,  8.22it/s, batch: 0 | bound: 544 | nc: 25 | ncall: 970825 | eff(%):  3.389 | loglstar:   -inf < -289.519 <    inf | logz: -350.221 +/-  0.464 | dlogz:  0.087 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 33115it [2:19:54,  4.09it/s, batch: 0 | bound: 548 | nc: 25 | ncall: 977639 | eff(%):  3.386 | loglstar:   -inf < -289.306 <    inf | logz: -350.219 +/-  0.464 | dlogz:  0.060 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 33118it [2:20:13,  3.51s/it, batch: 0 | bound: 549 | nc: 176 | ncall: 979332 | eff(%):  3.380 | loglstar:   -inf < -289.303 <    inf | logz: -350.219 +/-  0.464 | dlogz:  0.059 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 43018it [2:48:38,  4.25it/s, batch: 4 | bound: 672 | nc: 25 | ncall: 1216162 | eff(%):  3.537 | loglstar: -301.540 < -288.535 < -292.624 | logz: -350.216 +/-  0.460 | stop:  0.984]

# %%
# structure_d2o
# structure_pmw
plt.plot(*structure_d2o.sld_profile(),label="structure_d2o")
# structure_d2o.plot()
# plt.ylabel('SLD ($10^{-6} \AA^{-2})$')
# plt.xlabel('distance  $(\AA)$')

plt.plot(*structure_pmw.sld_profile(),label="structure_pmw")
# structure_pmw.plot()
plt.ylabel('SLD ($10^{-6} \AA^{-2})$')
plt.xlabel('distance  $(\AA)$')
plt.legend()
plt.show();

# %%
gobjective.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
objective1.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
objective2.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
span = [(0,5000),(0,1.5),(0,0.4),(-10**3,10**3)]
fig, axes = dyplot.runplot(res1,span=span, color='black', mark_final_live=False,
                           logplot=False)

# %%
print(-min(res1["logvol"]))
# Out:
# 72.77303628499271

# %%
fig, axes = dyplot.traceplot(res1, #truths=np.zeros(fitter.nDim()),
                             show_titles=True, trace_cmap='plasma',
                             quantiles=[0.025, 0.5, 0.975])
fig.tight_layout()

# %%
print("model1: d2o", model1.scale, model1.bkg)
print("model2: pmw", model2.scale, model2.bkg)
# Out:
# model1: d2o <Parameter:    'scale'    , value=0.780244          , bounds=[0.5, 1.5]> <Parameter:     'bkg'     , value=2.9607e-06          , bounds=[3.72e-07, 3.348e-06]>
# model2: pmw <Parameter:    'scale'    , value=0.639173          , bounds=[0.5, 1.5]> <Parameter:     'bkg'     , value=3.71771e-06          , bounds=[6.74e-07, 6.066e-06]>

# %%
print(structure_d2o)
# Out:
# ________________________________________________________________________________
# Structure:
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# LipidLeaflet(Parameter(value=47.344243290506896, name='mono, dodab - area_per_molecule', vary=True, bounds=Interval(lb=30, ub=120), constraint=None), SLD([Parameter(value=2.1799999999999825e-06, name='mono, dodab - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=54.6, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=1.9836057773471685, name='bilayer - thickness heads', vary=True, bounds=Interval(lb=0.284375, ub=1.9906249999999999), constraint=None), SLD([Parameter(value=-0.00037430000000000005, name='mono, dodab - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=997.1999999999999, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=5.371521120987924, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=5.19375, ub=36.356249999999996), constraint=None), Parameter(value=0.11967642454107363, name='bilayer - roughness', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=0.11967642454107363, name='bilayer - roughness', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=5.4779463522555405, name='mono, dodab - D2O in head - sld', vary=True, bounds=Interval(lb=5.35, ub=6.35), constraint=None), Parameter(value=0.0, name='mono, dodab - D2O in head - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=0.0, name='mono, dodab - air in tail - sld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='mono, dodab - air in tail - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=False, name='')
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter: 'D2O - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'D2O - sld'  , value=6.06253          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'D2O - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# LipidLeaflet(Parameter(value=60.42989171027635, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=60, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=6.458447088039208, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=1.3346774193548387, ub=9.34274193548387), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=15.563499024037881, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3.791129032258065, ub=26.537903225806453), constraint=None), Parameter(value=10.477671099338524, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=20), constraint=None), Parameter(value=10.477671099338524, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=20), constraint=None), head_solvent=SLD([Parameter(value=6.33449408913851, name='D2O in bilayer - sld', vary=True, bounds=Interval(lb=5.35, ub=6.35), constraint=None), Parameter(value=0.0, name='D2O in bilayer - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=None, reverse_monolayer=False, name='')
# LipidLeaflet(Parameter(value=60.42989171027635, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=60, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=6.458447088039208, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=1.3346774193548387, ub=9.34274193548387), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=15.563499024037881, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3.791129032258065, ub=26.537903225806453), constraint=None), Parameter(value=10.477671099338524, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=20), constraint=None), Parameter(value=10.477671099338524, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=20), constraint=None), head_solvent=SLD([Parameter(value=6.33449408913851, name='D2O in bilayer - sld', vary=True, bounds=Interval(lb=5.35, ub=6.35), constraint=None), Parameter(value=0.0, name='D2O in bilayer - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=None, reverse_monolayer=True, name='')
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter: 'D2O - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'D2O - sld'  , value=6.06253          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'D2O - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>

# %%
print(structure_pmw)
# Out:
# ________________________________________________________________________________
# Structure:
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# LipidLeaflet(Parameter(value=47.344243290506896, name='mono, dodab - area_per_molecule', vary=True, bounds=Interval(lb=30, ub=120), constraint=None), SLD([Parameter(value=2.1799999999999825e-06, name='mono, dodab - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=54.6, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=1.9836057773471685, name='bilayer - thickness heads', vary=True, bounds=Interval(lb=0.284375, ub=1.9906249999999999), constraint=None), SLD([Parameter(value=-0.00037430000000000005, name='mono, dodab - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=997.1999999999999, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=5.371521120987924, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=5.19375, ub=36.356249999999996), constraint=None), Parameter(value=0.11967642454107363, name='bilayer - roughness', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=0.11967642454107363, name='bilayer - roughness', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=3.294002388074195, name='mono, dodab - Protein Matched Water in head - sld', vary=True, bounds=Interval(lb=1.35, ub=3.35), constraint=None), Parameter(value=0.0, name='mono, dodab - Protein Matched Water in head - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=0.0, name='mono, dodab - air in tail - sld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='mono, dodab - air in tail - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=False, name='')
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'Protein Matched Water - thick', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Protein Matched Water - sld', value=2.29986          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Protein Matched Water - rough', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# LipidLeaflet(Parameter(value=60.42989171027635, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=60, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=6.458447088039208, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=1.3346774193548387, ub=9.34274193548387), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=15.563499024037881, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3.791129032258065, ub=26.537903225806453), constraint=None), Parameter(value=6.179559688645681, name='bilayer - rough_bot', vary=True, bounds=Interval(lb=0, ub=15), constraint=None), Parameter(value=6.179559688645681, name='bilayer - rough_bot', vary=True, bounds=Interval(lb=0, ub=15), constraint=None), head_solvent=SLD([Parameter(value=1.3503108002658406, name='Protein Matched Water in bilayer - sld', vary=True, bounds=Interval(lb=1.35, ub=3.35), constraint=None), Parameter(value=0.0, name='Protein Matched Water in bilayer - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=None, reverse_monolayer=False, name='')
# LipidLeaflet(Parameter(value=60.42989171027635, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=60, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=6.458447088039208, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=1.3346774193548387, ub=9.34274193548387), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name=' - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=15.563499024037881, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3.791129032258065, ub=26.537903225806453), constraint=None), Parameter(value=6.179559688645681, name='bilayer - rough_bot', vary=True, bounds=Interval(lb=0, ub=15), constraint=None), Parameter(value=6.179559688645681, name='bilayer - rough_bot', vary=True, bounds=Interval(lb=0, ub=15), constraint=None), head_solvent=SLD([Parameter(value=1.3503108002658406, name='Protein Matched Water in bilayer - sld', vary=True, bounds=Interval(lb=1.35, ub=3.35), constraint=None), Parameter(value=0.0, name='Protein Matched Water in bilayer - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=None, reverse_monolayer=True, name='')
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'Protein Matched Water - thick', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Protein Matched Water - sld', value=2.29986          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Protein Matched Water - rough', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
