# %%
import os.path
import numpy as np
import matplotlib.pyplot as plt
import scipy
import refnx
from refnx.dataset import ReflectDataset, Data1D
from refnx.analysis import Transform, CurveFitter, Objective, Model, Parameter, GlobalObjective
from refnx.reflect import SLD, Slab, ReflectModel
# from sepObjectiveGO import getObjective as gO
# import make_sim_data as msd
# import lipidBilayerAsGiven.SLD_maker 
import data_in as di
from protein.LipidLeafletWithProtein_builtOn2 import LipidLeafletWithProtien as LipidLeaflet


print('refnx: %s\nscipy: %s\nnumpy: %s' % (refnx.version.version,
                   scipy.version.version, np.version.version))
# %matplotlib inline
SEED = 12345
# Out:
# refnx: 0.1.9
# scipy: 1.3.0
# numpy: 1.16.4

# %%
# dataD2o = Data1D(data=di.data_in("lipidBilayerData/54696_97_edit.txt"))
# dataD2o.name="d2o"
# dataPmw = Data1D(data=di.data_in("lipidBilayerData/54699_00_edit.txt"))
# dataPmw.name="pmw"

dataAcmw = Data1D(data=di.data_in("protein/54613_14edit.txt"))
dataAcmw.name="acm"
dataPmw = Data1D(data=di.data_in("protein/54616_17edit.txt"))
dataPmw.name="pmw"
dataD2o = Data1D(data=di.data_in("protein/10_11_d2o.txt"))
dataD2o.name="d2o"
plt.errorbar(dataAcmw.data[0],dataAcmw.data[1],dataAcmw.data[2])
plt.errorbar(dataPmw.data[0],dataPmw.data[1],dataPmw.data[2])
plt.errorbar(dataD2o.data[0],dataD2o.data[1],dataD2o.data[2])
plt.yscale("log")
plt.show()
# Out:
# csv
# cvs-collecting
# csv
# cvs-collecting
# csv
# cvs-collecting

# %%
name = "bilayer"

d2o = SLD(6.07, "D2O")
pmw = SLD(2.35, "Protein Matched Water")
acmw = SLD(0.00, "ACMW")
air = SLD(0.00, "Air")

d2o.real.setp(vary=True, bounds=(5.8, 6.)) # bounds=(5.9, 6.35))
pmw.real.setp(vary=True, bounds=(1., 3.))
acmw.real.setp(vary=True, bounds=(-1, 1))

apm = Parameter(value=75, name='%s - area_per_molecule' % name,
                bounds=(75, 150), vary=True) #bounds=(60, 150), vary=True)

#Define all the neutron b's
bc = 0.6646e-4  #Carbon
bo = 0.5804e-4  #Oxygen
bh = -0.3739e-4 #Hydrogen
bp = 0.513e-4   #Phosphorus
bn = 0.936e-4   #Nitrogen
bd = 0.6671e-4  #Deuterium

#Formulae of the molecule sections...
CH2 = (1*bc) + (2*bh)
CH = (1*bc) + (1*bh)
CH3 = (1*bc) + (3*bh)
D2O = (2*bd) + (1*bo)
H2O = (2*bh) + (1*bo)

# Calculate mole fraction of D2O from the bulk SLD..
# d2o_molfr = (1/D2O-H2O)*(contrast*27.64)-H2O
# wMol = (d2o_molfr * D2O) + ((1-d2o_molfr)*H2O)

#sum b's of all the different fragments
b_tails = Parameter(value=(28*CH2) + (2*CH) + (2*CH3),
                       name='%s - b_tails_real' % name)

sum_popc_heads = (8*bo) + (1*bp) + (1*bn) + (2*bc) + (4*CH2) + (3*CH3) + (1*CH)
sum_popg_heads = (10*bo) + (1*bp) + (2*bc) + (4*CH2) + (2*CH) + (2*bh)
b_heads = Parameter(value=(3*(sum_popc_heads) + (sum_popg_heads))/4,
                        name='%s - b_heads_real' % name)

#monolayer compositions
#sum_m_tails = (34*CH2) + (2*CH3);
#sum_m_heads = (1*bn) + (2*CH3) + (Waters_per_headD * wMol);

#volumes of each fragment
vCH2 = 27.7
nCH2 = 30
vCH3 = 54.6
vm_tails = Parameter(value=(nCH2 * vCH2) + (2 * vCH3),
            name='%s - volume_tails' % name) #
vm_heads = Parameter(value=331,
            name='%s - volume_heads' % name)  #
vm_water = Parameter(value=29.7,
            name='%s - water_vm' % name)

#thickness
thickness_tails = Parameter(6., #value=vm_tails.value/apm.value,
            name='%s - thickness_tails' % name,
            bounds=(3, #(1-0.75)*vm_tails.value/apm.value,
                    9), #(1+0.75)*vm_tails.value/apm.value),
               vary=True)
thickness_heads = Parameter(value= 11., #vm_heads.value/apm.value,
            name='%s - thickness_heads' % name,
            bounds=(9, #(1-0.75)*vm_heads.value/apm.value,
                    20), #(1+0.75)*vm_heads.value/apm.value),
               vary=True)

rough_top = Parameter(value=2,
            name='%s - rough_top' % name,
            bounds=(0,10), vary=True)
rough_bot = rough_top
# rough_bot = Parameter(value=2.0,
#             name='%s - rough_bot' % name,
#             bounds=(0,10), vary=True)

waters_per_head = Parameter(
            value=2.8,
            name="{} - Waters Per Head".format(name),
            bounds=(5, 20), vary=True)

waters_per_tail = Parameter(
            value=1,
            name="{} - Waters Per Tail".format(name),
            bounds=(0, 10), vary=True)

# b_mscl = Parameter(
#             value= ,
#             name="{} - b_protein_real".format(name),
#             vary=False)

vm_mscl = Parameter(
            value=19749+74937.5,
            name="{} - volume_protein".format(name),
            vary=False)

PLRatio = Parameter(
            value= 0.5,
            name="{} - ratio protein to bilayer".format(name),
            bounds=(0.25, 0.75),vary=True)

# %%
# apm, b_heads, vm_heads, thickness_heads
# b_tails, vm_tails, thickness_tails, rough_head_tail
# rough_preceding_mono, head_solvent


# head_solvent_d2o = SLD(6.07, "D2O in bilayer")
# head_solvent_d2o.real.setp(6.07, vary=True, bounds=(5.35, 6.35))
upper_lipid_d2o = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
    vm_water, waters_per_head, waters_per_tail,
    vm_mscl, PLRatio, d2o, d2o,
    reverse_monolayer=False, name="upper_lipid_d2o")

lower_lipid_d2o = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
    vm_water, waters_per_head, waters_per_tail,
    vm_mscl, PLRatio, d2o, d2o,
    reverse_monolayer=True, name="lower_lipid_d2o")


# head_solvent_pmw = SLD(2.35, "Protein Matched Water in bilayer")
# head_solvent_pmw.real.setp(2.34, vary=True, bounds=(1.35, 3.35))
upper_lipid_pmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_bot, rough_bot,
    vm_water, waters_per_head, waters_per_tail,
    vm_mscl, PLRatio, pmw, pmw,
    reverse_monolayer=False, name="upper_lipid_pmw")

lower_lipid_pmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_bot, rough_bot,
    vm_water, waters_per_head, waters_per_tail,
    vm_mscl, PLRatio, pmw, pmw,
    reverse_monolayer=True, name="lower_lipid_pmw")


upper_lipid_acmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_bot, rough_bot,
    vm_water, waters_per_head, waters_per_tail,
    vm_mscl, PLRatio, acmw, acmw,
    reverse_monolayer=False, name="upper_lipid_acmw")

lower_lipid_acmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_bot, rough_bot,
    vm_water, waters_per_head, waters_per_tail,
    vm_mscl, PLRatio, acmw, acmw,
    reverse_monolayer=True, name="lower_lipid_acmw")

# %%
# name_m = "mono, dodab"
# APMD = Parameter(value=48, name='%s - area_per_molecule' % name_m,
#         bounds=(30,120), vary=True)

# # monolayer compositions
# m_tails = Parameter(value=(34*CH2) + (2*CH3),
#             name='%s - b_tails_real' % name_m)
# m_heads = Parameter(value=(1*bn) + (2*CH3),
#             name='%s - b_heads_real' % name_m)

# # monolayer volumes
# vm_m_tails = Parameter(value=vCH2*36,
#             name='%s - volume_tails' % name_m)
# vm_m_heads = Parameter(value=54.6,
#             name='%s - volume_heads' % name_m)

# # monolayer thicknesses
# tail_thick_m = Parameter(value=vm_m_tails.value / APMD.value,
#             name='%s - thickness_tails' % name_m,
#             bounds=((1-0.75)*vm_m_tails.value / APMD.value,
#                     (1+0.75)*vm_m_tails.value / APMD.value),
#                vary=True)
# head_thick_m = Parameter(value=vm_m_heads.value / APMD.value,
#             name='%s - thickness heads' % name_m,
#             bounds=((1-0.75)*vm_m_heads.value / APMD.value,
#                     (1+0.75)*vm_m_heads.value / APMD.value),
#                vary=True)

# roughness_m =  Parameter(value=5.8,
#             name='%s - roughness' % name_m,
#             bounds=(0,10), vary=True)


# water_vm_m = Parameter(value=vm_water,
#             name='%s - water_vm' % name_m)
# waters_per_head_m = Parameter(
#             value=2.8,
#             name="{} Waters Per Head".format(name_m),
#             vary=True,
#             bounds=(1, 20))
# waters_per_tail_m = Parameter(
#             value=0.,
#             name="{} Waters Per Tail".format(name_m),
#             vary=False)

# %%
# m_head_solvent_pmw=SLD(2.35, "mono, dodab - Protein Matched Water in head")
# m_head_solvent_pmw.real.setp(2.34, vary=True, bounds=(1.35, 3.35))
# m_air_in_tail=SLD(0, "mono, dodab - air in tail")

# dodab_pmw = LipidLeaflet(apm=APMD, b_heads=m_heads, vm_heads=vm_m_heads,
#     thickness_heads=head_thick_m, b_tails=m_tails, vm_tails=vm_m_tails,
#     thickness_tails=tail_thick_m, rough_head_tail=roughness_m,
#     rough_preceding_mono=roughness_m,
#     water_vm=vm_water, waters_per_head=waters_per_head_m,
#     waters_per_tail=waters_per_tail_m,
#     head_solvent=m_head_solvent_pmw, tail_solvent=m_air_in_tail) #mono

# m_head_solvent_d2o=SLD(6.07, "mono, dodab - D2O in head")
# m_head_solvent_d2o.real.setp(6.07, vary=True, bounds=(5.35, 6.35))
# dodab_d2o = LipidLeaflet(apm=APMD, b_heads=m_heads, vm_heads=vm_m_heads,
#     thickness_heads=head_thick_m, b_tails=m_tails, vm_tails=vm_m_tails,
#     thickness_tails=tail_thick_m, rough_head_tail=roughness_m,
#     water_vm=vm_water, waters_per_head=waters_per_head_m,
#     waters_per_tail=waters_per_tail_m,
#     rough_preceding_mono=roughness_m, head_solvent=m_head_solvent_d2o,
#                          tail_solvent=m_air_in_tail) #mono

# %%
# structure_d2o = air(0, 0) | dodab_d2o | d2o(0, 0) | upper_lipid_d2o | lower_lipid_d2o | d2o(0, 0)
# structure_pmw = air(0, 0) | dodab_pmw | pmw(0, 0) | upper_lipid_pmw | lower_lipid_pmw | pmw(0, 0)
# structure_d2o = air(0, 0) | d2o(0, 0) | upper_lipid_d2o | lower_lipid_d2o | d2o(0, 0)
# structure_pmw = air(0, 0) | pmw(0, 0) | upper_lipid_pmw | lower_lipid_pmw | pmw(0, 0)
#
#
# solution_thickness = Parameter(value=14.3, bounds=(6, 20), vary=True,
#             name='%s - thickness_solution' % name)

# rough_preceding_solution = Parameter(value=4.6, bounds=(0, 20), vary=True,
#             name='%s - rough_preceding_solution' % name)
# 
# structure_d2o[2].thick=solution_thickness#.setp(14.3, vary=True, bounds=(6, 20))
# structure_d2o[2].rough=rough_preceding_solution#.setp(4.6, vary=True, bounds=(3, 20))
# structure_pmw[2].thick=solution_thickness
# structure_pmw[2].rough=rough_preceding_solution
#
# structure_d2o[5].thick=solution_thickness
# structure_d2o[5].rough=rough_preceding_solution
# structure_pmw[5].thick=solution_thickness
# structure_pmw[5].rough=rough_preceding_solution

# to changing to
solution_thickness = Parameter(value=14.3, bounds=(6, 25), vary=True,
            name='thickness_solution')

rough_preceding_solution = Parameter(value=4.6, bounds=(0, 20), vary=True,
            name='rough_preceding_solution')

structure_d2o  = air(0, 0) | d2o(solution_thickness, rough_preceding_solution)  | upper_lipid_d2o  | lower_lipid_d2o  | d2o(solution_thickness, rough_preceding_solution)
structure_pmw  = air(0, 0) | pmw(solution_thickness, rough_preceding_solution)  | upper_lipid_pmw  | lower_lipid_pmw  | pmw(solution_thickness, rough_preceding_solution)
structure_acmw = air(0, 0) | acmw(solution_thickness, rough_preceding_solution) | upper_lipid_acmw | lower_lipid_acmw | acmw(solution_thickness, rough_preceding_solution)

structure_d2o.name = "d2o"
structure_pmw.name = "protein matched water"
structure_acmw.name = "ACMW"

plt.plot(*structure_d2o.sld_profile(),label="structure_d2o")
plt.ylabel('SLD /$10^{-6} \AA^{-2}$')
plt.xlabel('distance / $\AA$')
plt.plot(*structure_pmw.sld_profile(),label="structure_pmw")
plt.ylabel('SLD /$10^{-6} \AA^{-2}$')
plt.xlabel('distance / $\AA$')
plt.plot(*structure_acmw.sld_profile(),label="structure_acmw")
plt.ylabel('SLD /$10^{-6} \AA^{-2}$')
plt.xlabel('distance / $\AA$')
plt.show();
print(structure_d2o)
print(structure_pmw)
print(structure_acmw)
# Out:
# ________________________________________________________________________________
# Structure:       d2o
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=6.07          , bounds=[5.8, 6.0]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=4.6          , bounds=[0, 20]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# LipidLeaflet(Parameter(value=75.0, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=75, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='upper_lipid_d2o - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=11.0, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=9, ub=20), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='upper_lipid_d2o - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=6.0, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3, ub=9), constraint=None), Parameter(value=2.0, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=2.0, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=6.07, name='D2O - sld', vary=True, bounds=Interval(lb=5.8, ub=6.0), constraint=None), Parameter(value=0.0, name='D2O - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=6.07, name='D2O - sld', vary=True, bounds=Interval(lb=5.8, ub=6.0), constraint=None), Parameter(value=0.0, name='D2O - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=False, name='upper_lipid_d2o')
# LipidLeaflet(Parameter(value=75.0, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=75, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='lower_lipid_d2o - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=11.0, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=9, ub=20), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='lower_lipid_d2o - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=6.0, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3, ub=9), constraint=None), Parameter(value=2.0, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=2.0, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=6.07, name='D2O - sld', vary=True, bounds=Interval(lb=5.8, ub=6.0), constraint=None), Parameter(value=0.0, name='D2O - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=6.07, name='D2O - sld', vary=True, bounds=Interval(lb=5.8, ub=6.0), constraint=None), Parameter(value=0.0, name='D2O - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=True, name='lower_lipid_d2o')
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=6.07          , bounds=[5.8, 6.0]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=4.6          , bounds=[0, 20]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Structure: protein matched water
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.0, 3.0]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=4.6          , bounds=[0, 20]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# LipidLeaflet(Parameter(value=75.0, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=75, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='upper_lipid_pmw - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=11.0, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=9, ub=20), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='upper_lipid_pmw - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=6.0, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3, ub=9), constraint=None), Parameter(value=2.0, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=2.0, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=2.35, name='Protein Matched Water - sld', vary=True, bounds=Interval(lb=1.0, ub=3.0), constraint=None), Parameter(value=0.0, name='Protein Matched Water - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=2.35, name='Protein Matched Water - sld', vary=True, bounds=Interval(lb=1.0, ub=3.0), constraint=None), Parameter(value=0.0, name='Protein Matched Water - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=False, name='upper_lipid_pmw')
# LipidLeaflet(Parameter(value=75.0, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=75, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='lower_lipid_pmw - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=11.0, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=9, ub=20), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='lower_lipid_pmw - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=6.0, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3, ub=9), constraint=None), Parameter(value=2.0, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=2.0, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=2.35, name='Protein Matched Water - sld', vary=True, bounds=Interval(lb=1.0, ub=3.0), constraint=None), Parameter(value=0.0, name='Protein Matched Water - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=2.35, name='Protein Matched Water - sld', vary=True, bounds=Interval(lb=1.0, ub=3.0), constraint=None), Parameter(value=0.0, name='Protein Matched Water - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=True, name='lower_lipid_pmw')
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.0, 3.0]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=4.6          , bounds=[0, 20]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Structure:      ACMW
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:     'ACMW'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter: 'ACMW - sld'  , value=0          , bounds=[-1, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=4.6          , bounds=[0, 20]>
# <Parameter:'ACMW - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# LipidLeaflet(Parameter(value=75.0, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=75, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='upper_lipid_acmw - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=11.0, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=9, ub=20), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='upper_lipid_acmw - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=6.0, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3, ub=9), constraint=None), Parameter(value=2.0, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=2.0, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=0.0, name='ACMW - sld', vary=True, bounds=Interval(lb=-1, ub=1), constraint=None), Parameter(value=0.0, name='ACMW - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=0.0, name='ACMW - sld', vary=True, bounds=Interval(lb=-1, ub=1), constraint=None), Parameter(value=0.0, name='ACMW - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=False, name='upper_lipid_acmw')
# LipidLeaflet(Parameter(value=75.0, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=75, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='lower_lipid_acmw - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=11.0, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=9, ub=20), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='lower_lipid_acmw - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=6.0, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3, ub=9), constraint=None), Parameter(value=2.0, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=2.0, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=0.0, name='ACMW - sld', vary=True, bounds=Interval(lb=-1, ub=1), constraint=None), Parameter(value=0.0, name='ACMW - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=0.0, name='ACMW - sld', vary=True, bounds=Interval(lb=-1, ub=1), constraint=None), Parameter(value=0.0, name='ACMW - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=True, name='lower_lipid_acmw')
# ________________________________________________________________________________
# Parameters:     'ACMW'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter: 'ACMW - sld'  , value=0          , bounds=[-1, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=4.6          , bounds=[0, 20]>
# <Parameter:'ACMW - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>

# %%
print(structure_acmw.slabs())
print(structure_pmw.slabs())
print(structure_d2o.slabs())
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 1.43000000e+01  0.00000000e+00  0.00000000e+00  4.60000000e+00
#    0.00000000e+00]
#  [ 1.10000000e+01  3.81378907e-01  4.95124626e-09  2.00000000e+00
#    0.00000000e+00]
#  [ 6.00000000e+00 -2.95821734e-01 -1.75180685e-09  2.00000000e+00
#    0.00000000e+00]
#  [ 6.00000000e+00 -2.95821734e-01 -1.75180685e-09  2.00000000e+00
#    0.00000000e+00]
#  [ 1.10000000e+01  3.81378907e-01  4.95124626e-09  2.00000000e+00
#    0.00000000e+00]
#  [ 1.43000000e+01  0.00000000e+00  0.00000000e+00  4.60000000e+00
#    0.00000000e+00]]
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 1.43000000e+01  2.35000000e+00  0.00000000e+00  4.60000000e+00
#    0.00000000e+00]
#  [ 1.10000000e+01  6.41649153e-01  4.95124626e-09  2.00000000e+00
#    0.00000000e+00]
#  [ 6.00000000e+00 -2.83710546e-01 -1.75180685e-09  2.00000000e+00
#    0.00000000e+00]
#  [ 6.00000000e+00 -2.83710546e-01 -1.75180685e-09  2.00000000e+00
#    0.00000000e+00]
#  [ 1.10000000e+01  6.41649153e-01  4.95124626e-09  2.00000000e+00
#    0.00000000e+00]
#  [ 1.43000000e+01  2.35000000e+00  0.00000000e+00  4.60000000e+00
#    0.00000000e+00]]
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 1.43000000e+01  6.07000000e+00  0.00000000e+00  4.60000000e+00
#    0.00000000e+00]
#  [ 1.10000000e+01  1.05365141e+00  4.95124626e-09  2.00000000e+00
#    0.00000000e+00]
#  [ 6.00000000e+00 -2.64538795e-01 -1.75180685e-09  2.00000000e+00
#    0.00000000e+00]
#  [ 6.00000000e+00 -2.64538795e-01 -1.75180685e-09  2.00000000e+00
#    0.00000000e+00]
#  [ 1.10000000e+01  1.05365141e+00  4.95124626e-09  2.00000000e+00
#    0.00000000e+00]
#  [ 1.43000000e+01  6.07000000e+00  0.00000000e+00  4.60000000e+00
#    0.00000000e+00]]

# %%
print(dataD2o.y.max(), dataPmw.y.max(), dataAcmw.y.max())
print(dataD2o.y.min(), dataPmw.y.min(), dataAcmw.y.min())
model1 = ReflectModel(structure_d2o)
model1.scale.setp(1./dataD2o.y.max(), vary=False)
if dataD2o.y.min()<0:
    d2oUpBound = dataD2o.y.min() * 0.2
    d2oLoBound = dataD2o.y.min() * 1.8
else:
    d2oUpBound = dataD2o.y.min() * 1.8
    d2oLoBound = dataD2o.y.min() * 0.2
model1.bkg.setp(dataD2o.y.min(),vary=True,bounds=(d2oLoBound, d2oUpBound))

model2 = ReflectModel(structure_pmw)
model2.scale.setp(1./dataPmw.y.max(), vary=False)
if dataPmw.y.min()<0:
    pmwUpBound = dataPmw.y.min() * 0.2
    pmwLoBound = dataPmw.y.min() * 1.8
else:
    pmwUpBound = dataPmw.y.min() * 1.8
    pmwLoBound = dataPmw.y.min() * 0.2
model2.bkg.setp(dataPmw.y.min(),vary=True,bounds=(pmwLoBound, pmwUpBound))

model3 = ReflectModel(structure_acmw)
model3.scale.setp(1./dataAcmw.y.max(), vary=False)
if dataAcmw.y.min()<0:
    acmwUpBound = dataAcmw.y.min() * 0.2
    acmwLoBound = dataAcmw.y.min() * 1.8
else:
    acmwUpBound = dataAcmw.y.min() * 1.8
    acmwLoBound = dataAcmw.y.min() * 0.2
model3.bkg.setp(dataAcmw.y.min(),vary=True,bounds=(acmwLoBound, acmwUpBound))

objective1 = Objective(model1, dataD2o, transform=Transform("logY"))
objective2 = Objective(model2, dataPmw, transform=Transform("logY"))
objective3 = Objective(model3, dataAcmw, transform=Transform("logY"))
gobjective = GlobalObjective([objective1])#,objective2,objective3])
# Out:
# 0.562 0.0655 0.000924
# 1.8e-06 3.02e-06 1.73e-06

# %%
choose = 2
if choose==0:
    fitter = CurveFitter(gobjective)
    res = fitter.fit("differential_evolution", target="nlpost")#, seed=SEED)
if choose==1:
    fitter = CurveFitter(gobjective)
    fitter.sample(400)
    fitter.reset()
    res = fitter.sample(15, nthin=100)
if choose==2:
    from dynesty import DynamicNestedSampler
    from dynesty import plotting as dyplot
    from CFitter import CFitter
    fitter = CFitter(gobjective)
    # DynamicNestedSampler
    DNSampler = DynamicNestedSampler(fitter.logl, fitter.priorTransform, fitter.nDim())
    DNSampler.run_nested(dlogz_init=0.05) # was 0.01
    res1 = DNSampler.results
# Out:
# 6428it [06:08, 14.94it/s, batch: 0 | bound: 72 | nc: 25 | ncall: 132715 | eff(%):  4.825 | loglstar:   -inf < -94952.709 <    inf | logz: -94970.238 +/-  0.259 | dlogz: 665.815 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 6872it [06:39, 14.62it/s, batch: 0 | bound: 79 | nc: 25 | ncall: 143819 | eff(%):  4.762 | loglstar:   -inf < -94810.635 <    inf | logz: -94829.282 +/-  0.264 | dlogz: 524.023 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 7202it [07:02, 15.05it/s, batch: 0 | bound: 85 | nc: 25 | ncall: 152191 | eff(%):  4.717 | loglstar:   -inf < -94723.125 <    inf | logz: -94742.118 +/-  0.268 | dlogz: 438.116 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 7342it [07:12, 14.99it/s, batch: 0 | bound: 87 | nc: 25 | ncall: 155772 | eff(%):  4.698 | loglstar:   -inf < -94690.998 <    inf | logz: -94709.907 +/-  0.270 | dlogz: 405.564 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 7720it [07:38, 13.12it/s, batch: 0 | bound: 94 | nc: 25 | ncall: 165314 | eff(%):  4.656 | loglstar:   -inf < -94609.399 <    inf | logz: -94630.038 +/-  0.278 | dlogz: 408.805 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 7852it [07:48, 14.75it/s, batch: 0 | bound: 96 | nc: 25 | ncall: 168648 | eff(%):  4.642 | loglstar:   -inf < -94586.397 <    inf | logz: -94606.171 +/-  0.276 | dlogz: 384.464 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 7998it [07:58, 14.99it/s, batch: 0 | bound: 98 | nc: 25 | ncall: 172358 | eff(%):  4.627 | loglstar:   -inf < -94556.014 <    inf | logz: -94576.573 +/-  0.282 | dlogz: 354.660 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 8120it [08:07, 14.65it/s, batch: 0 | bound: 100 | nc: 25 | ncall: 175478 | eff(%):  4.614 | loglstar:   -inf < -94533.887 <    inf | logz: -94554.873 +/-  0.281 | dlogz: 332.769 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 8220it [08:15, 15.48it/s, batch: 0 | bound: 102 | nc: 25 | ncall: 178226 | eff(%):  4.599 | loglstar:   -inf < -94515.758 <    inf | logz: -94536.310 +/-  0.281 | dlogz: 313.868 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 8342it [08:24, 14.08it/s, batch: 0 | bound: 104 | nc: 25 | ncall: 181365 | eff(%):  4.587 | loglstar:   -inf < -94491.988 <    inf | logz: -94512.813 +/-  0.282 | dlogz: 290.136 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 8480it [08:33, 14.90it/s, batch: 0 | bound: 106 | nc: 25 | ncall: 184831 | eff(%):  4.576 | loglstar:   -inf < -94469.124 <    inf | logz: -94490.148 +/-  0.283 | dlogz: 324.742 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 8728it [08:51, 14.62it/s, batch: 0 | bound: 110 | nc: 25 | ncall: 191239 | eff(%):  4.552 | loglstar:   -inf < -94432.136 <    inf | logz: -94454.056 +/-  0.288 | dlogz: 288.221 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 9118it [09:18, 14.90it/s, batch: 0 | bound: 116 | nc: 25 | ncall: 201091 | eff(%):  4.523 | loglstar:   -inf < -94381.437 <    inf | logz: -94403.727 +/-  0.292 | dlogz: 237.050 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 9446it [09:41, 14.40it/s, batch: 0 | bound: 121 | nc: 25 | ncall: 209414 | eff(%):  4.500 | loglstar:   -inf < -94345.925 <    inf | logz: -94368.093 +/-  0.293 | dlogz: 219.796 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 9568it [09:51, 15.48it/s, batch: 0 | bound: 123 | nc: 25 | ncall: 212683 | eff(%):  4.488 | loglstar:   -inf < -94335.269 <    inf | logz: -94358.114 +/-  0.296 | dlogz: 209.601 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 9776it [10:06, 14.44it/s, batch: 0 | bound: 126 | nc: 25 | ncall: 218073 | eff(%):  4.473 | loglstar:   -inf < -94315.743 <    inf | logz: -94338.979 +/-  0.299 | dlogz: 190.052 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 9898it [10:15, 14.88it/s, batch: 0 | bound: 128 | nc: 25 | ncall: 221268 | eff(%):  4.463 | loglstar:   -inf < -94306.629 <    inf | logz: -94329.687 +/-  0.297 | dlogz: 180.482 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 10090it [10:28, 15.27it/s, batch: 0 | bound: 131 | nc: 25 | ncall: 226231 | eff(%):  4.450 | loglstar:   -inf < -94289.324 <    inf | logz: -94313.149 +/-  0.303 | dlogz: 163.591 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 10292it [10:44, 14.72it/s, batch: 0 | bound: 134 | nc: 25 | ncall: 231535 | eff(%):  4.436 | loglstar:   -inf < -94272.170 <    inf | logz: -94296.124 +/-  0.304 | dlogz: 146.142 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 10398it [10:52, 15.01it/s, batch: 0 | bound: 136 | nc: 25 | ncall: 234358 | eff(%):  4.427 | loglstar:   -inf < -94263.214 <    inf | logz: -94288.039 +/-  0.308 | dlogz: 143.581 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 10594it [11:06, 15.56it/s, batch: 0 | bound: 139 | nc: 25 | ncall: 239318 | eff(%):  4.418 | loglstar:   -inf < -94250.193 <    inf | logz: -94274.878 +/-  0.307 | dlogz: 132.143 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 10824it [11:22, 14.64it/s, batch: 0 | bound: 143 | nc: 25 | ncall: 245203 | eff(%):  4.405 | loglstar:   -inf < -94234.980 <    inf | logz: -94259.610 +/-  0.308 | dlogz: 116.394 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 10926it [11:30, 15.37it/s, batch: 0 | bound: 145 | nc: 25 | ncall: 248003 | eff(%):  4.397 | loglstar:   -inf < -94227.820 <    inf | logz: -94252.900 +/-  0.311 | dlogz: 113.461 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 11046it [11:39, 14.97it/s, batch: 0 | bound: 147 | nc: 25 | ncall: 251136 | eff(%):  4.390 | loglstar:   -inf < -94219.800 <    inf | logz: -94245.354 +/-  0.314 | dlogz: 105.690 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 11168it [11:48, 15.16it/s, batch: 0 | bound: 149 | nc: 25 | ncall: 254229 | eff(%):  4.384 | loglstar:   -inf < -94212.122 <    inf | logz: -94237.707 +/-  0.313 | dlogz: 97.784 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 11362it [12:01, 14.71it/s, batch: 0 | bound: 152 | nc: 25 | ncall: 259129 | eff(%):  4.376 | loglstar:   -inf < -94202.234 <    inf | logz: -94227.899 +/-  0.315 | dlogz: 100.369 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 11492it [12:11, 15.02it/s, batch: 0 | bound: 154 | nc: 25 | ncall: 262569 | eff(%):  4.368 | loglstar:   -inf < -94195.803 <    inf | logz: -94221.942 +/-  0.317 | dlogz: 94.161 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 11772it [12:31, 14.58it/s, batch: 0 | bound: 158 | nc: 25 | ncall: 269710 | eff(%):  4.357 | loglstar:   -inf < -94181.409 <    inf | logz: -94207.762 +/-  0.319 | dlogz: 108.659 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 11864it [12:38, 15.20it/s, batch: 0 | bound: 160 | nc: 25 | ncall: 272113 | eff(%):  4.352 | loglstar:   -inf < -94176.692 <    inf | logz: -94203.557 +/-  0.322 | dlogz: 104.285 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12050it [12:52, 14.71it/s, batch: 0 | bound: 163 | nc: 25 | ncall: 276942 | eff(%):  4.343 | loglstar:   -inf < -94167.587 <    inf | logz: -94194.688 +/-  0.323 | dlogz: 95.037 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12170it [13:01, 14.49it/s, batch: 0 | bound: 165 | nc: 25 | ncall: 280137 | eff(%):  4.337 | loglstar:   -inf < -94162.511 <    inf | logz: -94189.671 +/-  0.324 | dlogz: 89.774 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12638it [13:34, 14.34it/s, batch: 0 | bound: 172 | nc: 25 | ncall: 291999 | eff(%):  4.321 | loglstar:   -inf < -94145.423 <    inf | logz: -94173.395 +/-  0.328 | dlogz: 87.137 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12918it [13:54, 16.07it/s, batch: 0 | bound: 176 | nc: 25 | ncall: 299379 | eff(%):  4.308 | loglstar:   -inf < -94135.535 <    inf | logz: -94164.218 +/-  0.332 | dlogz: 77.406 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13058it [14:03, 16.04it/s, batch: 0 | bound: 178 | nc: 25 | ncall: 303050 | eff(%):  4.302 | loglstar:   -inf < -94131.416 <    inf | logz: -94160.223 +/-  0.333 | dlogz: 73.126 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13188it [14:14, 15.86it/s, batch: 0 | bound: 181 | nc: 25 | ncall: 307200 | eff(%):  4.286 | loglstar:   -inf < -94127.362 <    inf | logz: -94156.413 +/-  0.334 | dlogz: 69.056 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13324it [14:24, 16.11it/s, batch: 0 | bound: 183 | nc: 25 | ncall: 310692 | eff(%):  4.282 | loglstar:   -inf < -94123.447 <    inf | logz: -94152.606 +/-  0.335 | dlogz: 64.973 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13528it [14:38, 16.11it/s, batch: 0 | bound: 186 | nc: 25 | ncall: 316068 | eff(%):  4.273 | loglstar:   -inf < -94117.663 <    inf | logz: -94147.190 +/-  0.338 | dlogz: 60.813 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13820it [14:57, 15.61it/s, batch: 0 | bound: 191 | nc: 25 | ncall: 323485 | eff(%):  4.266 | loglstar:   -inf < -94110.163 <    inf | logz: -94140.132 +/-  0.340 | dlogz: 54.438 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13924it [15:06, 16.20it/s, batch: 0 | bound: 193 | nc: 25 | ncall: 326617 | eff(%):  4.257 | loglstar:   -inf < -94107.321 <    inf | logz: -94137.634 +/-  0.342 | dlogz: 51.735 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14160it [15:22, 16.30it/s, batch: 0 | bound: 197 | nc: 25 | ncall: 332926 | eff(%):  4.247 | loglstar:   -inf < -94101.725 <    inf | logz: -94132.173 +/-  0.344 | dlogz: 45.796 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14418it [15:40, 16.37it/s, batch: 0 | bound: 201 | nc: 25 | ncall: 339809 | eff(%):  4.237 | loglstar:   -inf < -94095.598 <    inf | logz: -94126.920 +/-  0.347 | dlogz: 42.530 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14852it [16:08, 15.03it/s, batch: 0 | bound: 207 | nc: 25 | ncall: 350796 | eff(%):  4.228 | loglstar:   -inf < -94087.531 <    inf | logz: -94119.211 +/-  0.350 | dlogz: 34.994 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15060it [16:22, 16.06it/s, batch: 0 | bound: 210 | nc: 25 | ncall: 356284 | eff(%):  4.221 | loglstar:   -inf < -94083.864 <    inf | logz: -94115.895 +/-  0.352 | dlogz: 39.645 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15146it [16:30, 16.63it/s, batch: 0 | bound: 212 | nc: 25 | ncall: 359131 | eff(%):  4.212 | loglstar:   -inf < -94082.343 <    inf | logz: -94114.595 +/-  0.353 | dlogz: 38.173 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15356it [16:44, 17.08it/s, batch: 0 | bound: 215 | nc: 25 | ncall: 364462 | eff(%):  4.208 | loglstar:   -inf < -94078.433 <    inf | logz: -94111.262 +/-  0.356 | dlogz: 34.423 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15600it [17:01, 16.12it/s, batch: 0 | bound: 219 | nc: 25 | ncall: 370998 | eff(%):  4.199 | loglstar:   -inf < -94074.401 <    inf | logz: -94107.495 +/-  0.358 | dlogz: 30.166 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15718it [17:10, 16.40it/s, batch: 0 | bound: 221 | nc: 25 | ncall: 374140 | eff(%):  4.195 | loglstar:   -inf < -94072.638 <    inf | logz: -94105.957 +/-  0.358 | dlogz: 30.988 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15840it [17:19, 16.21it/s, batch: 0 | bound: 223 | nc: 25 | ncall: 377482 | eff(%):  4.191 | loglstar:   -inf < -94071.052 <    inf | logz: -94104.481 +/-  0.359 | dlogz: 29.266 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15926it [17:26, 16.83it/s, batch: 0 | bound: 225 | nc: 25 | ncall: 380184 | eff(%):  4.184 | loglstar:   -inf < -94069.994 <    inf | logz: -94103.529 +/-  0.360 | dlogz: 28.141 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 16112it [17:39, 16.75it/s, batch: 0 | bound: 228 | nc: 25 | ncall: 385154 | eff(%):  4.178 | loglstar:   -inf < -94067.425 <    inf | logz: -94101.381 +/-  0.362 | dlogz: 29.000 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 16370it [17:58, 16.01it/s, batch: 0 | bound: 232 | nc: 25 | ncall: 392391 | eff(%):  4.167 | loglstar:   -inf < -94064.210 <    inf | logz: -94098.549 +/-  0.364 | dlogz: 25.651 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 16502it [18:08, 16.17it/s, batch: 0 | bound: 234 | nc: 25 | ncall: 395960 | eff(%):  4.162 | loglstar:   -inf < -94062.849 <    inf | logz: -94097.315 +/-  0.365 | dlogz: 24.153 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 16660it [18:19, 16.43it/s, batch: 0 | bound: 237 | nc: 25 | ncall: 400339 | eff(%):  4.156 | loglstar:   -inf < -94060.972 <    inf | logz: -94095.887 +/-  0.366 | dlogz: 22.410 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 16826it [18:32, 15.99it/s, batch: 0 | bound: 240 | nc: 25 | ncall: 405180 | eff(%):  4.148 | loglstar:   -inf < -94059.186 <    inf | logz: -94094.340 +/-  0.368 | dlogz: 23.599 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 17146it [18:54, 16.13it/s, batch: 0 | bound: 245 | nc: 25 | ncall: 413786 | eff(%):  4.139 | loglstar:   -inf < -94055.978 <    inf | logz: -94091.574 +/-  0.371 | dlogz: 20.192 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 17236it [19:02, 17.14it/s, batch: 0 | bound: 247 | nc: 25 | ncall: 416386 | eff(%):  4.134 | loglstar:   -inf < -94054.969 <    inf | logz: -94090.827 +/-  0.372 | dlogz: 19.266 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 17554it [19:23, 16.60it/s, batch: 0 | bound: 252 | nc: 25 | ncall: 424927 | eff(%):  4.126 | loglstar:   -inf < -94052.099 <    inf | logz: -94088.426 +/-  0.375 | dlogz: 18.618 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 17830it [19:42, 16.35it/s, batch: 0 | bound: 256 | nc: 25 | ncall: 432049 | eff(%):  4.122 | loglstar:   -inf < -94049.831 <    inf | logz: -94086.618 +/-  0.377 | dlogz: 16.943 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 17923it [19:50, 16.64it/s, batch: 0 | bound: 258 | nc: 25 | ncall: 434794 | eff(%):  4.117 | loglstar:   -inf < -94048.985 <    inf | logz: -94085.986 +/-  0.378 | dlogz: 16.125 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 18023it [19:58, 16.25it/s, batch: 0 | bound: 260 | nc: 25 | ncall: 437827 | eff(%):  4.112 | loglstar:   -inf < -94048.249 <    inf | logz: -94085.353 +/-  0.379 | dlogz: 15.291 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 18143it [20:07, 16.76it/s, batch: 0 | bound: 262 | nc: 25 | ncall: 441083 | eff(%):  4.109 | loglstar:   -inf < -94047.195 <    inf | logz: -94084.595 +/-  0.380 | dlogz: 16.024 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 18347it [20:22, 16.83it/s, batch: 0 | bound: 265 | nc: 25 | ncall: 446559 | eff(%):  4.104 | loglstar:   -inf < -94045.652 <    inf | logz: -94083.364 +/-  0.382 | dlogz: 15.754 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 18527it [20:35, 16.12it/s, batch: 0 | bound: 268 | nc: 25 | ncall: 451557 | eff(%):  4.098 | loglstar:   -inf < -94044.175 <    inf | logz: -94082.325 +/-  0.383 | dlogz: 14.356 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 18749it [20:51, 16.25it/s, batch: 0 | bound: 272 | nc: 25 | ncall: 457725 | eff(%):  4.092 | loglstar:   -inf < -94042.640 <    inf | logz: -94081.110 +/-  0.385 | dlogz: 15.620 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 19105it [21:15, 16.61it/s, batch: 0 | bound: 277 | nc: 25 | ncall: 467064 | eff(%):  4.086 | loglstar:   -inf < -94040.512 <    inf | logz: -94079.485 +/-  0.388 | dlogz: 13.283 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 19219it [21:24, 17.25it/s, batch: 0 | bound: 279 | nc: 25 | ncall: 470237 | eff(%):  4.083 | loglstar:   -inf < -94039.933 <    inf | logz: -94079.012 +/-  0.388 | dlogz: 12.581 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 19407it [21:38, 16.82it/s, batch: 0 | bound: 282 | nc: 25 | ncall: 475365 | eff(%):  4.078 | loglstar:   -inf < -94038.879 <    inf | logz: -94078.302 +/-  0.390 | dlogz: 11.496 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 19530it [21:48, 16.23it/s, batch: 0 | bound: 284 | nc: 25 | ncall: 478794 | eff(%):  4.075 | loglstar:   -inf < -94038.242 <    inf | logz: -94077.849 +/-  0.391 | dlogz: 12.138 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 19726it [22:02, 16.26it/s, batch: 0 | bound: 287 | nc: 25 | ncall: 483992 | eff(%):  4.071 | loglstar:   -inf < -94037.241 <    inf | logz: -94077.176 +/-  0.392 | dlogz: 11.073 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 19826it [22:11, 16.78it/s, batch: 0 | bound: 289 | nc: 25 | ncall: 487244 | eff(%):  4.065 | loglstar:   -inf < -94036.807 <    inf | logz: -94076.858 +/-  0.393 | dlogz: 13.460 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 19950it [22:22, 16.23it/s, batch: 0 | bound: 291 | nc: 25 | ncall: 490936 | eff(%):  4.060 | loglstar:   -inf < -94036.140 <    inf | logz: -94076.462 +/-  0.394 | dlogz: 12.815 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 20106it [22:35, 16.75it/s, batch: 0 | bound: 294 | nc: 25 | ncall: 495719 | eff(%):  4.052 | loglstar:   -inf < -94035.396 <    inf | logz: -94075.972 +/-  0.395 | dlogz: 12.014 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 20198it [22:43, 17.02it/s, batch: 0 | bound: 296 | nc: 25 | ncall: 498523 | eff(%):  4.048 | loglstar:   -inf < -94035.024 <    inf | logz: -94075.708 +/-  0.396 | dlogz: 14.488 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 20380it [22:56, 15.10it/s, batch: 0 | bound: 299 | nc: 25 | ncall: 503620 | eff(%):  4.043 | loglstar:   -inf < -94034.242 <    inf | logz: -94075.206 +/-  0.397 | dlogz: 13.622 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 20588it [23:11, 16.24it/s, batch: 0 | bound: 302 | nc: 25 | ncall: 509147 | eff(%):  4.040 | loglstar:   -inf < -94033.280 <    inf | logz: -94074.660 +/-  0.399 | dlogz: 12.660 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 20682it [23:19, 15.79it/s, batch: 0 | bound: 304 | nc: 25 | ncall: 511852 | eff(%):  4.037 | loglstar:   -inf < -94032.873 <    inf | logz: -94074.423 +/-  0.399 | dlogz: 12.236 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 21026it [23:43, 15.93it/s, batch: 0 | bound: 309 | nc: 25 | ncall: 521029 | eff(%):  4.032 | loglstar:   -inf < -94031.395 <    inf | logz: -94073.586 +/-  0.402 | dlogz: 10.711 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 21136it [23:53, 16.59it/s, batch: 0 | bound: 311 | nc: 25 | ncall: 524707 | eff(%):  4.024 | loglstar:   -inf < -94030.930 <    inf | logz: -94073.321 +/-  0.403 | dlogz: 10.226 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 21386it [24:12, 16.20it/s, batch: 0 | bound: 315 | nc: 25 | ncall: 531650 | eff(%):  4.019 | loglstar:   -inf < -94029.938 <    inf | logz: -94072.758 +/-  0.405 | dlogz:  9.164 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 21492it [24:21, 16.53it/s, batch: 0 | bound: 317 | nc: 25 | ncall: 535055 | eff(%):  4.013 | loglstar:   -inf < -94029.559 <    inf | logz: -94072.532 +/-  0.406 | dlogz:  8.726 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 21598it [24:32, 16.72it/s, batch: 0 | bound: 319 | nc: 25 | ncall: 538632 | eff(%):  4.006 | loglstar:   -inf < -94029.164 <    inf | logz: -94072.316 +/-  0.407 | dlogz:  9.508 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 21780it [24:46, 16.35it/s, batch: 0 | bound: 322 | nc: 25 | ncall: 543836 | eff(%):  4.001 | loglstar:   -inf < -94028.536 <    inf | logz: -94071.962 +/-  0.408 | dlogz:  8.791 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 22182it [25:14, 16.65it/s, batch: 0 | bound: 328 | nc: 25 | ncall: 554458 | eff(%):  3.997 | loglstar:   -inf < -94027.208 <    inf | logz: -94071.290 +/-  0.411 | dlogz:  7.316 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 22313it [25:24, 16.42it/s, batch: 0 | bound: 330 | nc: 25 | ncall: 558164 | eff(%):  3.994 | loglstar:   -inf < -94026.733 <    inf | logz: -94071.082 +/-  0.412 | dlogz:  6.846 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 22691it [25:50, 17.02it/s, batch: 0 | bound: 336 | nc: 25 | ncall: 568292 | eff(%):  3.989 | loglstar:   -inf < -94025.503 <    inf | logz: -94070.504 +/-  0.414 | dlogz:  5.763 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 22811it [26:00, 15.96it/s, batch: 0 | bound: 338 | nc: 25 | ncall: 571652 | eff(%):  3.987 | loglstar:   -inf < -94025.156 <    inf | logz: -94070.335 +/-  0.415 | dlogz:  5.356 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 23167it [26:24, 16.26it/s, batch: 0 | bound: 343 | nc: 25 | ncall: 580860 | eff(%):  3.985 | loglstar:   -inf < -94024.170 <    inf | logz: -94069.897 +/-  0.417 | dlogz:  4.958 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 23337it [26:37, 16.05it/s, batch: 0 | bound: 346 | nc: 25 | ncall: 585299 | eff(%):  3.984 | loglstar:   -inf < -94023.756 <    inf | logz: -94069.713 +/-  0.418 | dlogz:  4.439 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 23467it [26:48, 15.56it/s, batch: 0 | bound: 348 | nc: 25 | ncall: 588981 | eff(%):  3.981 | loglstar:   -inf < -94023.473 <    inf | logz: -94069.587 +/-  0.419 | dlogz:  4.059 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 23849it [27:15, 14.03it/s, batch: 0 | bound: 354 | nc: 25 | ncall: 599339 | eff(%):  3.976 | loglstar:   -inf < -94022.587 <    inf | logz: -94069.269 +/-  0.421 | dlogz:  3.400 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 23993it [27:28, 16.24it/s, batch: 0 | bound: 357 | nc: 25 | ncall: 603732 | eff(%):  3.971 | loglstar:   -inf < -94022.295 <    inf | logz: -94069.165 +/-  0.422 | dlogz:  3.025 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 24159it [27:41, 16.36it/s, batch: 0 | bound: 360 | nc: 25 | ncall: 608544 | eff(%):  3.967 | loglstar:   -inf < -94021.964 <    inf | logz: -94069.058 +/-  0.422 | dlogz:  3.261 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 24321it [27:54, 16.69it/s, batch: 0 | bound: 363 | nc: 25 | ncall: 613134 | eff(%):  3.963 | loglstar:   -inf < -94021.628 <    inf | logz: -94068.962 +/-  0.423 | dlogz:  3.217 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 24541it [28:11, 16.38it/s, batch: 0 | bound: 367 | nc: 25 | ncall: 619295 | eff(%):  3.960 | loglstar:   -inf < -94021.227 <    inf | logz: -94068.847 +/-  0.424 | dlogz:  3.479 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 24695it [28:23, 16.42it/s, batch: 0 | bound: 370 | nc: 25 | ncall: 623475 | eff(%):  3.958 | loglstar:   -inf < -94020.951 <    inf | logz: -94068.776 +/-  0.424 | dlogz:  3.115 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 24885it [28:38, 16.59it/s, batch: 0 | bound: 373 | nc: 25 | ncall: 628646 | eff(%):  3.955 | loglstar:   -inf < -94020.591 <    inf | logz: -94068.697 +/-  0.425 | dlogz:  2.682 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 25018it [28:48, 16.21it/s, batch: 0 | bound: 375 | nc: 25 | ncall: 632340 | eff(%):  3.953 | loglstar:   -inf < -94020.358 <    inf | logz: -94068.646 +/-  0.426 | dlogz:  2.390 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 25278it [29:07, 16.33it/s, batch: 0 | bound: 379 | nc: 25 | ncall: 639060 | eff(%):  3.952 | loglstar:   -inf < -94019.944 <    inf | logz: -94068.559 +/-  0.426 | dlogz:  1.857 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 25596it [29:30, 16.65it/s, batch: 0 | bound: 384 | nc: 25 | ncall: 647772 | eff(%):  3.948 | loglstar:   -inf < -94019.472 <    inf | logz: -94068.475 +/-  0.427 | dlogz:  1.290 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 25852it [29:49, 16.39it/s, batch: 0 | bound: 388 | nc: 25 | ncall: 654690 | eff(%):  3.946 | loglstar:   -inf < -94019.082 <    inf | logz: -94068.420 +/-  0.428 | dlogz:  1.354 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 26016it [30:01, 16.47it/s, batch: 0 | bound: 391 | nc: 25 | ncall: 659011 | eff(%):  3.945 | loglstar:   -inf < -94018.862 <    inf | logz: -94068.390 +/-  0.428 | dlogz:  1.101 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 26120it [30:10, 16.59it/s, batch: 0 | bound: 393 | nc: 25 | ncall: 661958 | eff(%):  3.943 | loglstar:   -inf < -94018.717 <    inf | logz: -94068.373 +/-  0.428 | dlogz:  0.957 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 26292it [30:24, 16.24it/s, batch: 0 | bound: 396 | nc: 25 | ncall: 666793 | eff(%):  3.940 | loglstar:   -inf < -94018.504 <    inf | logz: -94068.347 +/-  0.429 | dlogz:  0.746 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 26760it [30:56, 16.04it/s, batch: 0 | bound: 403 | nc: 25 | ncall: 678877 | eff(%):  3.939 | loglstar:   -inf < -94018.004 <    inf | logz: -94068.297 +/-  0.430 | dlogz:  0.401 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 27082it [31:20, 15.31it/s, batch: 0 | bound: 408 | nc: 25 | ncall: 687386 | eff(%):  3.937 | loglstar:   -inf < -94017.676 <    inf | logz: -94068.274 +/-  0.430 | dlogz:  0.310 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 27252it [31:33, 16.27it/s, batch: 0 | bound: 411 | nc: 25 | ncall: 692084 | eff(%):  3.935 | loglstar:   -inf < -94017.496 <    inf | logz: -94068.264 +/-  0.430 | dlogz:  0.348 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 27428it [31:47, 15.99it/s, batch: 0 | bound: 414 | nc: 25 | ncall: 696801 | eff(%):  3.933 | loglstar:   -inf < -94017.306 <    inf | logz: -94068.256 +/-  0.430 | dlogz:  0.255 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 27603it [32:01, 16.20it/s, batch: 0 | bound: 417 | nc: 25 | ncall: 701810 | eff(%):  3.930 | loglstar:   -inf < -94017.137 <    inf | logz: -94068.249 +/-  0.430 | dlogz:  0.185 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 28005it [32:29, 16.09it/s, batch: 0 | bound: 423 | nc: 25 | ncall: 712421 | eff(%):  3.928 | loglstar:   -inf < -94016.785 <    inf | logz: -94068.238 +/-  0.430 | dlogz:  0.086 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 40125it [47:46, 14.00it/s, batch: 5 | bound: 579 | nc: 25 | ncall: 1003585 | eff(%):  3.998 | loglstar: -94026.977 < -94016.308 < -94019.116 | logz: -94068.347 +/-  0.423 | stop:  0.987]

# %%
print(res1)
# [['bkg', nan],
#  ['thickness_solution', nan],
#  ['D2O - sld', nan],
#  ['rough_preceding_solution', nan],
#  ['bilayer - area_per_molecule', nan],
#  ['bilayer - thickness_heads', nan],
#  ['bilayer - thickness_tails', nan],
#  ['bilayer - rough_top', nan],
#  ['bilayer - Waters Per Head', nan],
#  ['bilayer - Waters Per Tail', nan],
#  ['bilayer - ratio protein to bilayer', nan],
#  ['bkg', nan],
#  ['Protein Matched Water - sld', nan],
#  ['bkg', nan],
#  ['ACMW - sld', nan]]
# Out:
#          niter: 40125
#          ncall: array([1, 1, 1, ..., 1, 1, 1])
#            eff: 3.9981665728363818
#        samples: array([[1.90675065e-06, 2.28713722e+01, 5.88858157e+00, ...,
#         8.70379660e+00, 9.45172244e+00, 3.99975428e-01],
#        [2.24593869e-06, 2.34863402e+01, 5.98437131e+00, ...,
#         1.33233496e+01, 6.08481300e+00, 5.73575267e-01],
#        [6.00748956e-07, 2.46801187e+01, 5.96301030e+00, ...,
#         8.86611471e+00, 4.36716429e+00, 6.06077343e-01],
#        ...,
#        [1.76604959e-06, 1.08511698e+01, 5.80000484e+00, ...,
#         1.97980454e+01, 4.65988985e+00, 7.34775198e-01],
#        [1.93353529e-06, 1.08327548e+01, 5.80002390e+00, ...,
#         1.99978781e+01, 4.04511866e+00, 7.46768284e-01],
#        [1.80669374e-06, 1.08315716e+01, 5.80001269e+00, ...,
#         1.98912511e+01, 4.41074244e+00, 7.45491367e-01]])
#     samples_id: array([ 84, 164, 498, ..., 441,  62, 398], dtype=int64)
#  samples_batch: array([0, 0, 0, ..., 0, 0, 0])
#     samples_it: array([    0,     0,     0, ..., 27416, 27277, 27225])
#      samples_u: array([[5.37066197e-01, 8.87966959e-01, 4.42907865e-01, ...,
#         2.46919773e-01, 9.45172244e-01, 2.99950856e-01],
#        [6.54839824e-01, 9.20333696e-01, 9.21856540e-01, ...,
#         5.54889975e-01, 6.08481300e-01, 6.47150535e-01],
#        [8.35933873e-02, 9.83164141e-01, 8.15051491e-01, ...,
#         2.57740981e-01, 4.36716429e-01, 7.12154686e-01],
#        ...,
#        [4.88211665e-01, 2.55324726e-01, 2.42049582e-05, ...,
#         9.86536362e-01, 4.65988985e-01, 9.69550396e-01],
#        [5.46366421e-01, 2.54355516e-01, 1.19497905e-04, ...,
#         9.99858537e-01, 4.04511866e-01, 9.93536567e-01],
#        [5.02324217e-01, 2.54293241e-01, 6.34641979e-05, ...,
#         9.92750075e-01, 4.41074244e-01, 9.90982733e-01]])
#      samples_n: array([500, 500, 500, ...,   3,   2,   1])
#          logwt: array([-151758.38954849, -147130.57202488, -146947.12107557, ...,
#         -94078.13690758,  -94078.11576451,  -94077.95242292])
#           logl: array([-151751.47979521, -147123.66027359, -146940.20732628, ...,
#         -94014.9964729 ,  -94014.98874853,  -94014.69174674])
#         logvol: array([-1.99800266e-03, -3.99600533e-03, -5.99400799e-03, ...,
#        -6.20245490e+01, -6.24300141e+01, -6.31231612e+01])
#           logz: array([-151758.38954849, -147130.57202488, -146947.12107557, ...,
#         -94068.3624444 ,  -94068.3623863 ,  -94068.3623179 ])
#        logzerr: array([0.1661668 , 0.16619086, 0.16621487, ..., 0.41971231, 0.42005378,
#        0.42075928])
#    information: array([ 6.90975215,  6.91175339,  6.91375031, ..., 46.29313262,
#        46.29348624, 46.29391414])
#    batch_nlive: array([500, 500, 500, 500, 500, 500])
#   batch_bounds: array([[           -inf,             inf],
#        [-94024.14964145, -94019.98902456],
#        [-94024.96778758, -94024.14859024],
#        [-94025.7639173 , -94024.96751709],
#        [-94026.39723799, -94021.21147982],
#        [-94026.97741429, -94019.11579691]])
#          bound: [<dynesty.bounding.UnitCube object at 0x000001E3A7B89F60>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7931048>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B79310B8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7931A20>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7931358>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7931588>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7EC5630>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7931390>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7EE0320>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3A7B89828>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7EE0A20>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7EE0400>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7EE0DA0>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7EC5CC0>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B785E5F8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B785EB00>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B700B5F8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B700BCF8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7EE0B00>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AACB83C8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AACB8978>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3A9862048>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AACB8898>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3A9862128>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3A9862978>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3A9862898>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3A9862FD0>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3ABD82128>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3ABD82CF8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3ABD82898>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AABA49E8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B785E6D8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7319828>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7319048>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7319FD0>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AAB6A828>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AAB6A908>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AABA43C8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3A936A198>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3A936A0B8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3A936A978>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AA8980B8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3A936A898>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AA898198>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AA898F28>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7319F28>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AA8AA6D8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AA8AAE48>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AA898828>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7346518>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7346CF8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AAC61518>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AAC615F8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B7346C18>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B6FCE4E0>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3AA8AAD68>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B6FCE710>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B6FCEB70>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B6FCE0B8>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B6FCEFD0>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3B6FCEF60>, <dynesty.bounding.MultiEllipsoid object at 0x000001E3A7DEF400>, <dynesty.bounding.Mul ...
#     bound_iter: array([  0,   0,   0, ..., 427, 427, 427])
#  samples_bound: array([  0,   0,   0, ..., 414, 412, 411])
#          scale: array([1.        , 1.        , 1.        , ..., 0.55499483, 0.55499483,
#        0.55499483])

# %%
print(structure_acmw.slabs())
print(structure_pmw.slabs())
print(structure_d2o.slabs())
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 1.08582586e+01  0.00000000e+00  0.00000000e+00  1.99974170e+01
#    0.00000000e+00]
#  [ 1.99676686e+01  1.55972123e-01  2.19318192e-08  5.95809136e-01
#    0.00000000e+00]
#  [ 4.74124462e+00 -2.77916465e-01 -3.05808115e-09  5.95809136e-01
#    0.00000000e+00]
#  [ 4.74124462e+00 -2.77916465e-01 -3.05808115e-09  5.95809136e-01
#    0.00000000e+00]
#  [ 1.99676686e+01  1.55972123e-01  2.19318192e-08  5.95809136e-01
#    0.00000000e+00]
#  [ 1.08582586e+01  0.00000000e+00  0.00000000e+00  1.99974170e+01
#    0.00000000e+00]]
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 1.08582586e+01  2.35000000e+00  0.00000000e+00  1.99974170e+01
#    0.00000000e+00]
#  [ 1.99676686e+01  1.21842237e+00  2.19318192e-08  5.95809136e-01
#    0.00000000e+00]
#  [ 4.74124462e+00 -3.81156007e-01 -3.05808115e-09  5.95809136e-01
#    0.00000000e+00]
#  [ 4.74124462e+00 -3.81156007e-01 -3.05808115e-09  5.95809136e-01
#    0.00000000e+00]
#  [ 1.99676686e+01  1.21842237e+00  2.19318192e-08  5.95809136e-01
#    0.00000000e+00]
#  [ 1.08582586e+01  2.35000000e+00  0.00000000e+00  1.99974170e+01
#    0.00000000e+00]]
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 1.08582586e+01  5.80000265e+00  0.00000000e+00  1.99974170e+01
#    0.00000000e+00]
#  [ 1.99676686e+01  2.77819094e+00  2.19318192e-08  5.95809136e-01
#    0.00000000e+00]
#  [ 4.74124462e+00 -5.32720557e-01 -3.05808115e-09  5.95809136e-01
#    0.00000000e+00]
#  [ 4.74124462e+00 -5.32720557e-01 -3.05808115e-09  5.95809136e-01
#    0.00000000e+00]
#  [ 1.99676686e+01  2.77819094e+00  2.19318192e-08  5.95809136e-01
#    0.00000000e+00]
#  [ 1.08582586e+01  5.80000265e+00  0.00000000e+00  1.99974170e+01
#    0.00000000e+00]]

# %%
# structure_d2o
# structure_pmw
plt.plot(*structure_d2o.sld_profile(),label="structure_d2o")
# structure_d2o.plot()
# plt.ylabel('SLD ($10^{-6} \AA^{-2})$')
# plt.xlabel('distance  $(\AA)$')

plt.plot(*structure_pmw.sld_profile(),label="structure_pmw")
# structure_pmw.plot()
plt.ylabel('SLD ($10^{-6} \AA^{-2})$')
plt.xlabel('distance  $(\AA)$')

plt.plot(*structure_acmw.sld_profile(),label="structure_acmw")
# structure_pmw.plot()
plt.ylabel('SLD ($10^{-6} \AA^{-2})$')
plt.xlabel('distance  $(\AA)$')
plt.legend()
plt.show();

# %%
if choose==1:
    gobjective.plot(samples=300)
else:
    gobjective.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
if choose==1:
    objective1.plot(samples=300)
else:
    objective1.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
if choose==1:
    objective2.plot(samples=300)
else:
    objective2.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
if choose==1:
    objective3.plot(samples=300)
else:
    objective3.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
print("model1: d2o", model1.scale, model1.bkg)
print("model2: pmw", model2.scale, model2.bkg)
print("model3: acmw", model3.scale, model3.bkg)
# Out:
# model1: d2o <Parameter:    'scale'    , value=1.77936 (fixed)  , bounds=[-inf, inf]> <Parameter:     'bkg'     , value=1.99064e-06          , bounds=[3.6e-07, 3.24e-06]>
# model2: pmw <Parameter:    'scale'    , value=15.2672 (fixed)  , bounds=[-inf, inf]> <Parameter:     'bkg'     , value=3.02e-06          , bounds=[6.040000000000001e-07, 5.436e-06]>
# model3: acmw <Parameter:    'scale'    , value=1082.25 (fixed)  , bounds=[-inf, inf]> <Parameter:     'bkg'     , value=1.73e-06          , bounds=[3.46e-07, 3.114e-06]>

# %%
print(structure_d2o)
# Out:
# ________________________________________________________________________________
# Structure:       d2o
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter:'thickness_solution', value=10.8583          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=5.8          , bounds=[5.8, 6.0]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=19.9974          , bounds=[0, 20]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# LipidLeaflet(Parameter(value=149.6284079724398, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=75, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='upper_lipid_d2o - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=19.96766861493898, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=9, ub=20), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='upper_lipid_d2o - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=4.741244618306547, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3, ub=9), constraint=None), Parameter(value=0.5958091358657387, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=0.5958091358657387, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=5.800002648856968, name='D2O - sld', vary=True, bounds=Interval(lb=5.8, ub=6.0), constraint=None), Parameter(value=0.0, name='D2O - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=5.800002648856968, name='D2O - sld', vary=True, bounds=Interval(lb=5.8, ub=6.0), constraint=None), Parameter(value=0.0, name='D2O - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=False, name='upper_lipid_d2o')
# LipidLeaflet(Parameter(value=149.6284079724398, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=75, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='lower_lipid_d2o - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=19.96766861493898, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=9, ub=20), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='lower_lipid_d2o - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=4.741244618306547, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3, ub=9), constraint=None), Parameter(value=0.5958091358657387, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=0.5958091358657387, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=5.800002648856968, name='D2O - sld', vary=True, bounds=Interval(lb=5.8, ub=6.0), constraint=None), Parameter(value=0.0, name='D2O - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=5.800002648856968, name='D2O - sld', vary=True, bounds=Interval(lb=5.8, ub=6.0), constraint=None), Parameter(value=0.0, name='D2O - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=True, name='lower_lipid_d2o')
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter:'thickness_solution', value=10.8583          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=5.8          , bounds=[5.8, 6.0]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=19.9974          , bounds=[0, 20]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>

# %%
print(structure_pmw)
# Out:
# ________________________________________________________________________________
# Structure: protein matched water
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'thickness_solution', value=10.8583          , bounds=[6, 25]>
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.0, 3.0]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=19.9974          , bounds=[0, 20]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# LipidLeaflet(Parameter(value=149.6284079724398, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=75, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='upper_lipid_pmw - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=19.96766861493898, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=9, ub=20), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='upper_lipid_pmw - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=4.741244618306547, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3, ub=9), constraint=None), Parameter(value=0.5958091358657387, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=0.5958091358657387, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=2.35, name='Protein Matched Water - sld', vary=True, bounds=Interval(lb=1.0, ub=3.0), constraint=None), Parameter(value=0.0, name='Protein Matched Water - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=2.35, name='Protein Matched Water - sld', vary=True, bounds=Interval(lb=1.0, ub=3.0), constraint=None), Parameter(value=0.0, name='Protein Matched Water - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=False, name='upper_lipid_pmw')
# LipidLeaflet(Parameter(value=149.6284079724398, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=75, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='lower_lipid_pmw - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=19.96766861493898, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=9, ub=20), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='lower_lipid_pmw - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=4.741244618306547, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3, ub=9), constraint=None), Parameter(value=0.5958091358657387, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=0.5958091358657387, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=2.35, name='Protein Matched Water - sld', vary=True, bounds=Interval(lb=1.0, ub=3.0), constraint=None), Parameter(value=0.0, name='Protein Matched Water - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=2.35, name='Protein Matched Water - sld', vary=True, bounds=Interval(lb=1.0, ub=3.0), constraint=None), Parameter(value=0.0, name='Protein Matched Water - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=True, name='lower_lipid_pmw')
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'thickness_solution', value=10.8583          , bounds=[6, 25]>
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.0, 3.0]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=19.9974          , bounds=[0, 20]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>

# %%
print(structure_acmw)
# Out:
# ________________________________________________________________________________
# Structure:      ACMW
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:     'ACMW'
# <Parameter:'thickness_solution', value=10.8583          , bounds=[6, 25]>
# <Parameter: 'ACMW - sld'  , value=0          , bounds=[-1, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=19.9974          , bounds=[0, 20]>
# <Parameter:'ACMW - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# LipidLeaflet(Parameter(value=149.6284079724398, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=75, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='upper_lipid_acmw - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=19.96766861493898, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=9, ub=20), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='upper_lipid_acmw - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=4.741244618306547, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3, ub=9), constraint=None), Parameter(value=0.5958091358657387, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=0.5958091358657387, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=0.0, name='ACMW - sld', vary=True, bounds=Interval(lb=-1, ub=1), constraint=None), Parameter(value=0.0, name='ACMW - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=0.0, name='ACMW - sld', vary=True, bounds=Interval(lb=-1, ub=1), constraint=None), Parameter(value=0.0, name='ACMW - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=False, name='upper_lipid_acmw')
# LipidLeaflet(Parameter(value=149.6284079724398, name='bilayer - area_per_molecule', vary=True, bounds=Interval(lb=75, ub=150), constraint=None), SLD([Parameter(value=0.0006292750000000001, name='bilayer - b_heads_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='lower_lipid_acmw - b_heads_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=331.0, name='bilayer - volume_heads', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=19.96766861493898, name='bilayer - thickness_heads', vary=True, bounds=Interval(lb=9, ub=20), constraint=None), SLD([Parameter(value=-0.00026624000000000005, name='bilayer - b_tails_real', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=0.0, name='lower_lipid_acmw - b_tails_imag', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), Parameter(value=940.2, name='bilayer - volume_tails', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None), Parameter(value=4.741244618306547, name='bilayer - thickness_tails', vary=True, bounds=Interval(lb=3, ub=9), constraint=None), Parameter(value=0.5958091358657387, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), Parameter(value=0.5958091358657387, name='bilayer - rough_top', vary=True, bounds=Interval(lb=0, ub=10), constraint=None), head_solvent=SLD([Parameter(value=0.0, name='ACMW - sld', vary=True, bounds=Interval(lb=-1, ub=1), constraint=None), Parameter(value=0.0, name='ACMW - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), tail_solvent=SLD([Parameter(value=0.0, name='ACMW - sld', vary=True, bounds=Interval(lb=-1, ub=1), constraint=None), Parameter(value=0.0, name='ACMW - isld', vary=False, bounds=Interval(lb=-np.inf, ub=np.inf), constraint=None)], name=''), reverse_monolayer=True, name='lower_lipid_acmw')
# ________________________________________________________________________________
# Parameters:     'ACMW'
# <Parameter:'thickness_solution', value=10.8583          , bounds=[6, 25]>
# <Parameter: 'ACMW - sld'  , value=0          , bounds=[-1, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=19.9974          , bounds=[0, 20]>
# <Parameter:'ACMW - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>

# %%
print(structure_d2o.slabs())
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 1.08582586e+01  5.80000265e+00  0.00000000e+00  1.99974170e+01
#    0.00000000e+00]
#  [ 1.99676686e+01  2.77819094e+00  2.19318192e-08  5.95809136e-01
#    0.00000000e+00]
#  [ 4.74124462e+00 -5.32720557e-01 -3.05808115e-09  5.95809136e-01
#    0.00000000e+00]
#  [ 4.74124462e+00 -5.32720557e-01 -3.05808115e-09  5.95809136e-01
#    0.00000000e+00]
#  [ 1.99676686e+01  2.77819094e+00  2.19318192e-08  5.95809136e-01
#    0.00000000e+00]
#  [ 1.08582586e+01  5.80000265e+00  0.00000000e+00  1.99974170e+01
#    0.00000000e+00]]

# %%
print(structure_pmw.slabs())
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 1.08582586e+01  2.35000000e+00  0.00000000e+00  1.99974170e+01
#    0.00000000e+00]
#  [ 1.99676686e+01  1.21842237e+00  2.19318192e-08  5.95809136e-01
#    0.00000000e+00]
#  [ 4.74124462e+00 -3.81156007e-01 -3.05808115e-09  5.95809136e-01
#    0.00000000e+00]
#  [ 4.74124462e+00 -3.81156007e-01 -3.05808115e-09  5.95809136e-01
#    0.00000000e+00]
#  [ 1.99676686e+01  1.21842237e+00  2.19318192e-08  5.95809136e-01
#    0.00000000e+00]
#  [ 1.08582586e+01  2.35000000e+00  0.00000000e+00  1.99974170e+01
#    0.00000000e+00]]

# %%
print(structure_acmw.slabs())
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 1.08582586e+01  0.00000000e+00  0.00000000e+00  1.99974170e+01
#    0.00000000e+00]
#  [ 1.99676686e+01  1.55972123e-01  2.19318192e-08  5.95809136e-01
#    0.00000000e+00]
#  [ 4.74124462e+00 -2.77916465e-01 -3.05808115e-09  5.95809136e-01
#    0.00000000e+00]
#  [ 4.74124462e+00 -2.77916465e-01 -3.05808115e-09  5.95809136e-01
#    0.00000000e+00]
#  [ 1.99676686e+01  1.55972123e-01  2.19318192e-08  5.95809136e-01
#    0.00000000e+00]
#  [ 1.08582586e+01  0.00000000e+00  0.00000000e+00  1.99974170e+01
#    0.00000000e+00]]

# %%
if choose==2:
    # span = [(0,5000),(0,1.5),(0,0.4),(-10**3,10**3)] #span=span
    fig, axes = dyplot.runplot(res1, color='black', mark_final_live=False,
                               logplot=False)
# Out:
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])

# %%
if choose==2:
    print(-min(res1["logvol"])) # ?
# Out:
# 63.1231612472723

# %%
#gobjective.varying_parameters()
[[param.name,param.value] for param in gobjective.varying_parameters()]
# Out:
# [['bkg', 1.9906385752876108e-06],
#  ['thickness_solution', 10.858258623798413],
#  ['D2O - sld', 5.800002648856968],
#  ['rough_preceding_solution', 19.997416991226533],
#  ['bilayer - area_per_molecule', 149.6284079724398],
#  ['bilayer - thickness_heads', 19.96766861493898],
#  ['bilayer - thickness_tails', 4.741244618306547],
#  ['bilayer - rough_top', 0.5958091358657387],
#  ['bilayer - Waters Per Head', 19.73927521070464],
#  ['bilayer - Waters Per Tail', 4.37621783317672],
#  ['bilayer - ratio protein to bilayer', 0.7405386548696489]]

# %% [markdown]
# I believe correct values, leaflet roughness between head and tail is the same as the roughness preceeding the leaflet\
# class used is a modified version of the LipidLeaflet class native to refnx, its in the file\
# "protein" and called "LipidLeafletWithProtien"\
# volumes of head and tails are indirectly varied by changes in waters per head/tail\
# so the tails do not change volume\
# 1 'scale',\
# 2 'bkg',\
# 3 'mono, dodab - area_per_molecule',\
# 4 'mono, dodab - thickness heads',\
# 5 'mono, dodab - thickness_tails',\
# 6 'mono, dodab - roughness',\
# 7 'mono, dodab - D2O in head - sld',\
# 8 'mono, dodab Waters Per Head',\
# 9 'D2O - sld',\
# 10 'bilayer - area_per_molecule',\
# 11 'bilayer - thickness_heads',\
# 12 'bilayer - thickness_tails',\
# 13 'bilayer - rough_top',\
# 14 'D2O in bilayer - sld',\
# 15 'bilayer Waters Per Head',\
# 16 'scale',\
# 17 'bkg',\
# 18 'mono, dodab - Protein Matched Water in head - sld',\
# 19 'Protein Matched Water - sld',\
# 20 'bilayer - rough_bot',\
# 21 'Protein Matched Water in bilayer - sld'

# %%
if choose==2:
    labels = [param.name for param in gobjective.varying_parameters()]

    fig, axes = dyplot.traceplot(res1, labels = labels, #truths=np.zeros(fitter.nDim()),
                                 show_titles=True, trace_cmap='plasma',
                                 quantiles=[0.025, 0.5, 0.975])
    fig.tight_layout()

# %%
if choose==2:
    labels = [param.name for param in gobjective.varying_parameters()]

    fig, axes = dyplot.cornerpoints(res1, labels = labels#, #truths=np.zeros(fitter.nDim()),
                                 #show_titles=True,
                                 #trace_cmap='plasma',
                                 #quantiles=[0.025, 0.5, 0.975]
                                   )
    fig.tight_layout()
