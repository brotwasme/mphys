# %%
# from numpy import sqrt, square, divide, inf
from scipy.optimize import curve_fit
import data_in
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
file = "29553_54.dat"
data = data_in.data_in(file)

print(data.shape)
# print(data[0],data[:,0])
i=0
plt.figure(i)
i+=1
plt.errorbar(data[0],data[1],yerr=5*data[2],ecolor='r')
plt.yscale("log")
plt.show();
# Out:
# csv
# cvs-collecting
# (3, 68)
# <img src="data:image/png;base64,..." width="640">

# %%
print("errors:",data[2])
plt.figure(i)
i+=1
plt.plot(data[0],data[2]/data[1])
plt.yscale("log")
plt.show();
# print("ln errors:",np.log(data[2]))
# Out:
# errors: [5.37993e-03 4.58771e-03 4.03069e-03 3.47765e-03 2.99459e-03 2.64457e-03
#  2.38162e-03 2.96708e-03 3.39465e-03 1.43443e-03 7.67167e-04 4.77634e-04
#  3.27722e-04 2.37793e-04 1.73557e-04 1.25897e-04 9.90848e-05 7.57369e-05
#  5.96260e-05 4.74239e-05 3.87631e-05 3.12039e-05 2.35640e-05 1.96261e-05
#  1.66444e-05 1.41813e-05 1.19133e-05 9.86291e-06 8.25315e-06 6.89199e-06
#  5.69837e-06 4.72674e-06 3.92691e-06 3.28084e-06 2.65285e-06 2.42830e-06
#  2.14971e-06 1.68856e-06 1.33160e-06 1.11439e-06 9.26877e-07 7.41974e-07
#  6.15398e-07 5.35053e-07 4.96546e-07 4.42676e-07 4.27673e-07 4.09862e-07
#  3.81955e-07 3.62749e-07 3.43169e-07 3.26914e-07 3.10409e-07 3.04610e-07
#  2.98544e-07 2.85365e-07 2.74828e-07 2.88051e-07 2.93470e-07 3.08815e-07
#  3.22991e-07 3.53690e-07 3.63667e-07 3.99830e-07 4.16314e-07 4.26128e-07
#  4.51444e-07 4.83208e-07]
# <img src="data:image/png;base64,..." width="640">

# %%
import make_sim_data as msd
sim_dR = msd.main()

print("errors:",data[2])
print("sim errors:",sim_dR)
print("dif in errors:", data[2]-sim_dR)
relative_diff = (data[2]-sim_dR)/data[2]
print("relative_diff:",relative_diff)
print("relative_diff mean:",relative_diff.mean(), "relative_diff std:",relative_diff.std())
plt.figure(i)
i+=1
plt.plot(data[0],relative_diff)
# plt.yscale("log")
plt.show();
# Out:
# csv
# cvs-collecting
# out  [3.47819830e+02 8.77904741e+01 3.20810699e+03 9.49732939e-37
#  1.65307010e-05]
# var:  [[1.76447440e+01 1.39762075e+02 1.90993913e+00 2.55098590e+04
#   6.99628049e-05]
#  [1.39762075e+02 1.10704093e+03 1.51284720e+01 2.01610925e+05
#   5.54070662e-04]
#  [1.90993913e+00 1.51284720e+01 2.06742813e-01 2.73481708e+03
#   7.56735044e-06]
#  [2.55098590e+04 2.01610925e+05 2.73481708e+03 2.55670288e+08
#   1.48331018e-01]
#  [6.99628049e-05 5.54070662e-04 7.56735044e-06 1.48331018e-01
#   2.92147690e-10]]
# errors: [5.37993e-03 4.58771e-03 4.03069e-03 3.47765e-03 2.99459e-03 2.64457e-03
#  2.38162e-03 2.96708e-03 3.39465e-03 1.43443e-03 7.67167e-04 4.77634e-04
#  3.27722e-04 2.37793e-04 1.73557e-04 1.25897e-04 9.90848e-05 7.57369e-05
#  5.96260e-05 4.74239e-05 3.87631e-05 3.12039e-05 2.35640e-05 1.96261e-05
#  1.66444e-05 1.41813e-05 1.19133e-05 9.86291e-06 8.25315e-06 6.89199e-06
#  5.69837e-06 4.72674e-06 3.92691e-06 3.28084e-06 2.65285e-06 2.42830e-06
# ...
